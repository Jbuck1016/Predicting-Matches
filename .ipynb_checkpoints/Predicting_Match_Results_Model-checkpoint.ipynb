# %%
import soccerdata as sd
understat = sd.Understat(leagues=["ENG-Premier League", "ESP-La Liga", "GER-Bundesliga", "ITA-Serie A", "FRA-Ligue 1"], seasons=["2023/2024", "2022/2023", "2021/2022", "2020/2021", "2019/2020", "2018/2019", "2017/2018"])
# Out:
# [05/17/24 14:16:16] INFO     No custom team name replacements found. You can configure these in       ]8;id=466555;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=907260;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\jbuck\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=639753;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=941101;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#194\194]8;;\
#                              C:\Users\jbuck\soccerdata\config\league_dict.json.
#                     INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\Understat           ]8;id=609094;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=476265;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#92\92]8;;\

# %%
team_match_stats = understat.read_team_match_stats()
team_match_stats.head(1)
# Out:
#                                                        league_id  season_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester         1       2017
#
#                                                         game_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester     7119
#
#                                                                       date  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester 2017-08-11 19:45:00
#
#                                                         home_team_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            83
#
#                                                         away_team_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            75
#
#                                                        home_team  away_team  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester   Arsenal  Leicester
#
#                                                        away_team_code  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            LEI
#
#                                                        home_team_code  ...  \
# league             season game                                         ...
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            ARS  ...
#
#                                                         away_ppda  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester  13.545455
#
#                                                         away_deep_completions  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                      2
#
#                                                         home_points  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            3
#
#                                                         home_expected_points  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                2.0994
#
#                                                         home_goals  home_xg  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester           4  2.54329
#
#                                                         home_np_xg  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester     2.54329
#
#                                                         home_np_xg_difference  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                1.07834
#
#                                                         home_ppda  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester   5.444444
#
#                                                         home_deep_completions
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                     13
#
# [1 rows x 26 columns]

# %%
import pandas as pd
# Assuming 'team_match_stats' is your DataFrame and 'date' contains datetime objects
team_match_stats['date'] = pd.to_datetime(team_match_stats['date']).dt.date

# Display the DataFrame to confirm changes
print(team_match_stats[['date', 'home_team', 'away_team']])
# Out:
#                                                                         date  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            2017-08-11
#                           2017-08-12 Brighton-Manchester City     2017-08-12
#                           2017-08-12 Chelsea-Burnley              2017-08-12
#                           2017-08-12 Crystal Palace-Huddersfield  2017-08-12
#                           2017-08-12 Everton-Stoke                2017-08-12
# ...                                                                      ...
# ITA-Serie A        2324   2024-05-12 Juventus-Salernitana         2024-05-12
#                           2024-05-12 Lazio-Empoli                 2024-05-12
#                           2024-05-12 Verona-Torino                2024-05-12
#                           2024-05-13 Fiorentina-Monza             2024-05-13
#                           2024-05-13 Lecce-Udinese                2024-05-13
#
#                                                                        home_team  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                   Arsenal
#                           2017-08-12 Brighton-Manchester City           Brighton
#                           2017-08-12 Chelsea-Burnley                     Chelsea
#                           2017-08-12 Crystal Palace-Huddersfield  Crystal Palace
#                           2017-08-12 Everton-Stoke                       Everton
# ...                                                                          ...
# ITA-Serie A        2324   2024-05-12 Juventus-Salernitana               Juventus
#                           2024-05-12 Lazio-Empoli                          Lazio
#                           2024-05-12 Verona-Torino                        Verona
#                           2024-05-13 Fiorentina-Monza                 Fiorentina
#                           2024-05-13 Lecce-Udinese                         Lecce
#
#                                                                         away_team
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                  Leicester
#                           2017-08-12 Brighton-Manchester City     Manchester City
#                           2017-08-12 Chelsea-Burnley                      Burnley
#                           2017-08-12 Crystal Palace-Huddersfield     Huddersfield
#                           2017-08-12 Everton-Stoke                          Stoke
# ...                                                                           ...
# ITA-Serie A        2324   2024-05-12 Juventus-Salernitana             Salernitana
#                           2024-05-12 Lazio-Empoli                          Empoli
#                           2024-05-12 Verona-Torino                         Torino
#                           2024-05-13 Fiorentina-Monza                       Monza
#                           2024-05-13 Lecce-Udinese                        Udinese
#
# [12538 rows x 3 columns]

# %%
# Create a target variable for the match result
def determine_result(row):
    if row['home_goals'] > row['away_goals']:
        return 'Home win'
    elif row['home_goals'] < row['away_goals']:
        return 'Away win'
    else:
        return 'Draw'

team_match_stats['result'] = team_match_stats.apply(determine_result, axis=1)

# %%
import pandas as pd
# Create a season_start column 
team_match_stats['date'] = pd.to_datetime(team_match_stats['date'])
team_match_stats['season_start'] = team_match_stats['date'].apply(lambda x: x.year - 1 if x.month < 8 else x.year)

# %%
# Let's create some new features
team_match_stats.reset_index(drop=True, inplace=True)
team_match_stats.sort_values(['date'], inplace=True)

# %%
# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['goal_value_to_calculate'] = temp_df.apply(lambda y: y['home_goals'] if y['home_team'] == x else y['away_goals'], axis=1)
    temp_df['rolling_avg_goals'] = temp_df['goal_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_goals'] = row['rolling_avg_goals']
        else:
            team_match_stats.at[index, 'away_rolling_avg_goals'] = row['rolling_avg_goals']

# Do the same thing for xG
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['xG_value_to_calculate'] = temp_df.apply(lambda y: y['home_xg'] if y['home_team'] == x else y['away_xg'], axis=1)
    temp_df['rolling_avg_xG'] = temp_df['xG_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_xG'] = row['rolling_avg_xG']
        else:
            team_match_stats.at[index, 'away_rolling_avg_xG'] = row['rolling_avg_xG']



# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['ppda_value_to_calculate'] = temp_df.apply(lambda y: y['home_ppda'] if y['home_team'] == x else y['away_ppda'], axis=1)
    temp_df['rolling_avg_ppda'] = temp_df['ppda_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_ppda'] = row['rolling_avg_ppda']
        else:
            team_match_stats.at[index, 'away_rolling_avg_ppda'] = row['rolling_avg_ppda']

# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['deep_completions_value_to_calculate'] = temp_df.apply(lambda y: y['home_deep_completions'] if y['home_team'] == x else y['away_deep_completions'], axis=1)
    temp_df['rolling_avg_deep_completions'] = temp_df['deep_completions_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_deep_completions'] = row['rolling_avg_deep_completions']
        else:
            team_match_stats.at[index, 'away_rolling_avg_deep_completions'] = row['rolling_avg_deep_completions']

# %%
# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['goal_allowed_value_to_calculate'] = temp_df.apply(lambda y: y['away_goals'] if y['home_team'] == x else y['home_goals'], axis=1)
    temp_df['rolling_avg_goals_allowed'] = temp_df['goal_allowed_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_goals_allowed'] = row['rolling_avg_goals_allowed']
        else:
            team_match_stats.at[index, 'away_rolling_avg_goals_allowed'] = row['rolling_avg_goals_allowed']

# Do the same thing for xG
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['xG_allowed_value_to_calculate'] = temp_df.apply(lambda y: y['away_xg'] if y['home_team'] == x else y['home_xg'], axis=1)
    temp_df['rolling_avg_xG_allowed'] = temp_df['xG_allowed_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_xG_allowed'] = row['rolling_avg_xG_allowed']
        else:
            team_match_stats.at[index, 'away_rolling_avg_xG_allowed'] = row['rolling_avg_xG_allowed']

# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['ppda_allowed_value_to_calculate'] = temp_df.apply(lambda y: y['away_ppda'] if y['home_team'] == x else y['home_ppda'], axis=1)
    temp_df['rolling_avg_ppda_allowed'] = temp_df['ppda_allowed_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_ppda_allowed'] = row['rolling_avg_ppda_allowed']
        else:
            team_match_stats.at[index, 'away_rolling_avg_ppda_allowed'] = row['rolling_avg_ppda_allowed']

# Update the rolling average goals for the home team in the main dataset
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['deep_completions_allowed_value_to_calculate'] = temp_df.apply(lambda y: y['away_deep_completions'] if y['home_team'] == x else y['home_deep_completions'], axis=1)
    temp_df['rolling_avg_deep_completions_allowed'] = temp_df['deep_completions_allowed_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_deep_completions_allowed'] = row['rolling_avg_deep_completions_allowed']
        else:
            team_match_stats.at[index, 'away_rolling_avg_deep_completions_allowed'] = row['rolling_avg_deep_completions_allowed']

# Calculate home and away rolling average xG difference
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values('date')

    temp_df['xG_diff_value_to_calculate'] = temp_df.apply(lambda y: y['home_rolling_avg_xG'] - y['home_rolling_avg_xG_allowed'] if y['home_team'] == x else y['away_rolling_avg_xG'] - y['away_rolling_avg_xG_allowed'], axis=1)
    temp_df['rolling_avg_xG_diff'] = temp_df['xG_diff_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_xG_diff'] = row['rolling_avg_xG_diff']
        else:
            team_match_stats.at[index, 'away_rolling_avg_xG_diff'] = row['rolling_avg_xG_diff']

# Calculate home and away rolling average xG difference
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values('date')

    temp_df['deep_completions_diff_value_to_calculate'] = temp_df.apply(lambda y: y['home_rolling_avg_deep_completions'] - y['home_rolling_avg_deep_completions_allowed'] if y['home_team'] == x else y['away_rolling_avg_deep_completions'] - y['away_rolling_avg_deep_completions_allowed'], axis=1)
    temp_df['rolling_avg_deep_completions_diff'] = temp_df['deep_completions_diff_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_deep_completions_diff'] = row['rolling_avg_deep_completions_diff']
        else:
            team_match_stats.at[index, 'away_rolling_avg_deep_completions_diff'] = row['rolling_avg_deep_completions_diff']

# Calculate home and away rolling average xG difference
for x in team_match_stats.home_team.unique():
    temp_df = team_match_stats[(team_match_stats['home_team'] == x) | (team_match_stats['away_team'] == x)]
    temp_df = temp_df.sort_values('date')

    temp_df['goals_diff_value_to_calculate'] = temp_df.apply(lambda y: y['home_rolling_avg_goals'] - y['home_rolling_avg_goals_allowed'] if y['home_team'] == x else y['away_rolling_avg_goals'] - y['away_rolling_avg_goals_allowed'], axis=1)
    temp_df['rolling_avg_goals_diff'] = temp_df['goals_diff_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home_team'] == x:
            team_match_stats.at[index, 'home_rolling_avg_goals_diff'] = row['rolling_avg_goals_diff']
        else:
            team_match_stats.at[index, 'away_rolling_avg_goals_diff'] = row['rolling_avg_goals_diff']

# %%
print(team_match_stats.columns)
# Out:
# Index(['league_id', 'season_id', 'game_id', 'date', 'home_team_id',
#        'away_team_id', 'home_team', 'away_team', 'away_team_code',
#        'home_team_code', 'away_points', 'away_expected_points', 'away_goals',
#        'away_xg', 'away_np_xg', 'away_np_xg_difference', 'away_ppda',
#        'away_deep_completions', 'home_points', 'home_expected_points',
#        'home_goals', 'home_xg', 'home_np_xg', 'home_np_xg_difference',
#        'home_ppda', 'home_deep_completions', 'result', 'season_start',
#        'home_rolling_avg_goals_allowed', 'away_rolling_avg_goals_allowed',
#        'home_rolling_avg_xG_allowed', 'away_rolling_avg_xG_allowed',
#        'home_rolling_avg_ppda_allowed', 'away_rolling_avg_ppda_allowed',
#        'home_rolling_avg_deep_completions_allowed',
#        'away_rolling_avg_deep_completions_allowed', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG',
#        'home_rolling_avg_ppda', 'away_rolling_avg_ppda',
#        'home_rolling_avg_deep_completions',
#        'away_rolling_avg_deep_completions', 'home_rolling_avg_xG_diff',
#        'away_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff',
#        'away_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff',
#        'away_rolling_avg_goals_diff'],
#       dtype='object')

# %%
team_match_stats = team_match_stats.dropna(subset=['home_rolling_avg_goals', 'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG', 'home_rolling_avg_deep_completions', 'away_rolling_avg_deep_completions',
                                                    'home_rolling_avg_xG_diff', 'away_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff', 'away_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff', 'away_rolling_avg_goals_diff',
                                                    
                                                   'home_rolling_avg_deep_completions_allowed', 'away_rolling_avg_deep_completions_allowed', 'home_rolling_avg_xG_allowed', 'away_rolling_avg_xG_allowed', 'home_rolling_avg_goals_allowed', 'away_rolling_avg_goals_allowed', 
                                                 ])

# %%
team_match_stats.columns
# Out:
# Index(['league_id', 'season_id', 'game_id', 'date', 'home_team_id',
#        'away_team_id', 'home_team', 'away_team', 'away_team_code',
#        'home_team_code', 'away_points', 'away_expected_points', 'away_goals',
#        'away_xg', 'away_np_xg', 'away_np_xg_difference', 'away_ppda',
#        'away_deep_completions', 'home_points', 'home_expected_points',
#        'home_goals', 'home_xg', 'home_np_xg', 'home_np_xg_difference',
#        'home_ppda', 'home_deep_completions', 'result', 'season_start',
#        'home_rolling_avg_goals_allowed', 'away_rolling_avg_goals_allowed',
#        'home_rolling_avg_xG_allowed', 'away_rolling_avg_xG_allowed',
#        'home_rolling_avg_ppda_allowed', 'away_rolling_avg_ppda_allowed',
#        'home_rolling_avg_deep_completions_allowed',
#        'away_rolling_avg_deep_completions_allowed', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG',
#        'home_rolling_avg_ppda', 'away_rolling_avg_ppda',
#        'home_rolling_avg_deep_completions',
#        'away_rolling_avg_deep_completions', 'home_rolling_avg_xG_diff',
#        'away_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff',
#        'away_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff',
#        'away_rolling_avg_goals_diff'],
#       dtype='object')

# %%
team_match_stats[(team_match_stats['home_team'] == 'Arsenal') | (team_match_stats['away_team'] == 'Arsenal')][['date', 'home_team', 'away_team', 'home_rolling_avg_goals', 'away_rolling_avg_goals',
       'home_rolling_avg_xG', 'away_rolling_avg_xG', 'home_rolling_avg_ppda',
       'away_rolling_avg_ppda', 'home_rolling_avg_deep_completions',
       'away_rolling_avg_deep_completions', 'home_rolling_avg_goals_allowed',
       'away_rolling_avg_goals_allowed', 'home_rolling_avg_xG_allowed',
       'away_rolling_avg_xG_allowed', 'home_rolling_avg_ppda_allowed',
       'away_rolling_avg_ppda_allowed',
       'home_rolling_avg_deep_completions_allowed',
       'away_rolling_avg_deep_completions_allowed', 'home_rolling_avg_xG_diff',
       'away_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff',
       'away_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff',
       'away_rolling_avg_goals_diff']]
# Out:
#            date                home_team             away_team  \
# 27   2017-08-27                Liverpool               Arsenal
# 30   2017-09-09                  Arsenal           Bournemouth
# 48   2017-09-17                  Chelsea               Arsenal
# 59   2017-09-25                  Arsenal  West Bromwich Albion
# 67   2017-10-01                  Arsenal              Brighton
# ...         ...                      ...                   ...
# 2599 2024-04-14                  Arsenal           Aston Villa
# 2605 2024-04-20  Wolverhampton Wanderers               Arsenal
# 2610 2024-04-23                  Arsenal               Chelsea
# 2625 2024-04-28                Tottenham               Arsenal
# 2628 2024-05-04                  Arsenal           Bournemouth
#
#       home_rolling_avg_goals  away_rolling_avg_goals  home_rolling_avg_xG  \
# 27                  2.000000                2.000000             2.732635
# 30                  1.333333                0.333333             1.478229
# 48                  2.000000                1.750000             1.100068
# 59                  1.400000                0.800000             1.668817
# 67                  1.000000                1.000000             1.638791
# ...                      ...                     ...                  ...
# 2599                2.600000                1.400000             1.977410
# 2605                1.200000                1.400000             1.441742
# 2610                1.400000                3.400000             1.874448
# 2625                1.200000                2.400000             1.672495
# 2628                2.600000                1.600000             2.538054
#
#       away_rolling_avg_xG  home_rolling_avg_ppda  away_rolling_avg_ppda  \
# 27               1.974935               9.405530               5.274854
# 30               0.520252               6.911631              12.453373
# 48               1.730501              12.462579               7.117057
# 59               0.872150               7.700097              20.172222
# 67               0.570764               7.707208              15.401515
# ...                   ...                    ...                    ...
# 2599             1.155283              11.731169              14.046951
# 2605             1.860828              12.518275              11.065296
# 2610             2.724556              12.135730              11.203162
# 2625             2.463884               6.328759              12.555435
# 2628             1.987568              12.337906              10.580463
#
#       home_rolling_avg_deep_completions  ...  home_rolling_avg_ppda_allowed  \
# 27                            10.500000  ...                      16.183066
# 30                            12.333333  ...                      18.309304
# 48                             7.250000  ...                      15.368056
# 59                            10.800000  ...                      17.547811
# 67                            10.800000  ...                      17.088720
# ...                                 ...  ...                            ...
# 2599                          16.200000  ...                      18.143998
# 2605                           6.600000  ...                      12.160909
# 2610                          15.200000  ...                      13.920030
# 2625                          16.200000  ...                      13.345803
# 2628                          16.000000  ...                      13.210603
#
#       away_rolling_avg_ppda_allowed  \
# 27                        18.806061
# 30                        10.242273
# 48                        17.758293
# 59                         9.617836
# 67                        22.061928
# ...                             ...
# 2599                       9.488200
# 2605                      13.717808
# 2610                      16.424444
# 2625                      16.656485
# 2628                       8.480274
#
#       home_rolling_avg_deep_completions_allowed  \
# 27                                     3.000000
# 30                                     3.333333
# 48                                     4.250000
# 59                                     3.200000
# 67                                     3.600000
# ...                                         ...
# 2599                                   4.000000
# 2605                                   8.000000
# 2610                                   3.800000
# 2625                                   6.000000
# 2628                                   5.000000
#
#       away_rolling_avg_deep_completions_allowed  home_rolling_avg_xG_diff  \
# 27                                     3.000000                  0.439020
# 30                                     8.333333                  0.987239
# 48                                     3.000000                  0.608457
# 59                                     4.000000                  0.440492
# 67                                     6.400000                  0.407877
# ...                                         ...                       ...
# 2599                                  10.000000                  1.890755
# 2605                                   4.000000                 -0.713562
# 2610                                   7.000000                  1.448816
# 2625                                   3.800000                  0.694170
# 2628                                   9.600000                  1.344153
#
#       away_rolling_avg_xG_diff  home_rolling_avg_deep_completions_diff  \
# 27                    1.078340                                8.000000
# 30                   -0.956617                               11.000000
# 48                    0.526727                               -0.277778
# 59                    0.238560                               10.062500
# 67                   -1.136513                                9.570000
# ...                        ...                                     ...
# 2599                 -0.130442                               14.360000
# 2605                  1.726232                               -3.080000
# 2610                  0.294382                               13.160000
# 2625                  1.254876                               10.000000
# 2628                  0.484523                               12.160000
#
#       away_rolling_avg_deep_completions_diff  home_rolling_avg_goals_diff  \
# 27                                 11.000000                     0.000000
# 30                                  0.000000                     0.500000
# 48                                 10.333333                    -0.111111
# 59                                 -1.708333                    -0.145833
# 67                                 -7.910000                    -0.156667
# ...                                      ...                          ...
# 2599                                0.960000                     3.480000
# 2605                               13.800000                    -0.520000
# 2610                                0.560000                     2.560000
# 2625                               12.000000                     0.800000
# 2628                               -0.560000                     1.720000
#
#       away_rolling_avg_goals_diff
# 27                       1.000000
# 30                      -1.250000
# 48                      -0.111111
# 59                       0.666667
# 67                      -1.286667
# ...                           ...
# 2599                     0.160000
# 2605                     3.280000
# 2610                     0.200000
# 2625                     1.920000
# 2628                     0.280000
#
# [261 rows x 25 columns]

# %%
# Let's train a model to predict the match result
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

print(team_match_stats.columns)
# Out:
# Index(['league_id', 'season_id', 'game_id', 'date', 'home_team_id',
#        'away_team_id', 'home_team', 'away_team', 'away_team_code',
#        'home_team_code', 'away_points', 'away_expected_points', 'away_goals',
#        'away_xg', 'away_np_xg', 'away_np_xg_difference', 'away_ppda',
#        'away_deep_completions', 'home_points', 'home_expected_points',
#        'home_goals', 'home_xg', 'home_np_xg', 'home_np_xg_difference',
#        'home_ppda', 'home_deep_completions', 'result', 'season_start',
#        'home_rolling_avg_goals_allowed', 'away_rolling_avg_goals_allowed',
#        'home_rolling_avg_xG_allowed', 'away_rolling_avg_xG_allowed',
#        'home_rolling_avg_ppda_allowed', 'away_rolling_avg_ppda_allowed',
#        'home_rolling_avg_deep_completions_allowed',
#        'away_rolling_avg_deep_completions_allowed', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG',
#        'home_rolling_avg_ppda', 'away_rolling_avg_ppda',
#        'home_rolling_avg_deep_completions',
#        'away_rolling_avg_deep_completions', 'home_rolling_avg_xG_diff',
#        'away_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff',
#        'away_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff',
#        'away_rolling_avg_goals_diff'],
#       dtype='object')

# %%
import pandas as pd

# URL of the CSV file
url = 'https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/odds_data_for_model.csv'

# Load the CSV file into a DataFrame
odds_data = pd.read_csv(url)

odds_data
# Out:
#                    league  season                              game  \
# 0      ENG-Premier League    1819   2018-08-10 Man United-Leicester
# 1      ENG-Premier League    1819    2018-08-11 Bournemouth-Cardiff
# 2      ENG-Premier League    1819  2018-08-11 Fulham-Crystal Palace
# 3      ENG-Premier League    1819   2018-08-11 Huddersfield-Chelsea
# 4      ENG-Premier League    1819    2018-08-11 Newcastle-Tottenham
# ...                   ...     ...                               ...
# 10644         ITA-Serie A    2324            2024-05-05 Milan-Genoa
# 10645         ITA-Serie A    2324          2024-05-05 Roma-Juventus
# 10646         ITA-Serie A    2324      2024-05-05 Verona-Fiorentina
# 10647         ITA-Serie A    2324   2024-05-06 Salernitana-Atalanta
# 10648         ITA-Serie A    2324         2024-05-06 Udinese-Napoli
#
#              date     home_team       away_team  B365H  B365D  B365A
# 0      2018-08-10    Man United       Leicester   1.57    3.9   7.50
# 1      2018-08-11   Bournemouth         Cardiff   1.90    3.6   4.50
# 2      2018-08-11        Fulham  Crystal Palace   2.50    3.4   3.00
# 3      2018-08-11  Huddersfield         Chelsea   6.50    4.0   1.61
# 4      2018-08-11     Newcastle       Tottenham   3.90    3.5   2.04
# ...           ...           ...             ...    ...    ...    ...
# 10644  2024-05-05         Milan           Genoa   1.45    4.5   6.50
# 10645  2024-05-05          Roma        Juventus   2.88    3.1   2.70
# 10646  2024-05-05        Verona      Fiorentina   3.10    3.3   2.30
# 10647  2024-05-06   Salernitana        Atalanta   7.50    5.5   1.36
# 10648  2024-05-06       Udinese          Napoli   3.75    3.6   1.95
#
# [10649 rows x 9 columns]

# %%
# Convert 'season_start' to string if it's not and then filter
team_match_stats['season_start'] = team_match_stats['season_start'].astype(str)
team_match_stats = team_match_stats[team_match_stats['season_start'] != '2017']

# Verify by checking if '2017' still exists in the 'season_start' column
print(team_match_stats['season_start'].unique())
# Out:
# ['2018' '2019' '2020' '2021' '2022' '2023']

# %%
import pandas as pd

# Assuming odds_data and team_match_stats are your DataFrames
# Extract sets of teams from both home and away columns for each DataFrame
teams_in_odds = set(odds_data['home_team']).union(set(odds_data['away_team']))
teams_in_stats = set(team_match_stats['home_team']).union(set(team_match_stats['away_team']))

# Find teams in odds_data but not in team_match_stats
teams_in_odds_not_in_stats = teams_in_odds - teams_in_stats

# Find teams in team_match_stats but not in odds_data
teams_in_stats_not_in_odds = teams_in_stats - teams_in_odds

# Print the results
print("Teams in odds_data not in team_match_stats:", teams_in_odds_not_in_stats)
print("Teams in team_match_stats not in odds_data:", teams_in_stats_not_in_odds)
# Out:
# Teams in odds_data not in team_match_stats: set()
# Teams in team_match_stats not in odds_data: set()

# %%
# Define a dictionary to map names from odds_data to team_match_stats
name_mapping = {
    'Newcastle': 'Newcastle United',
    'Ath Bilbao': 'Athletic Club',
    'Dortmund': 'Borussia Dortmund',
    'Fortuna Dusseldorf': 'Fortuna Duesseldorf',
    'Ath Madrid': 'Atletico Madrid',
    'Mainz': 'Mainz 05',
    'Paris SG': 'Paris Saint Germain',
    'Bielefeld': 'Arminia Bielefeld',
    'FC Koln': 'FC Cologne',
    'RB Leipzig': 'RasenBallsport Leipzig',
    'Clermont': 'Clermont Foot',
    'Nurnberg': 'Nuernberg',
    'Greuther Furth': 'Greuther Fuerth',
    'Spal': 'SPAL 2013',
    'Stuttgart': 'VfB Stuttgart',
    "Nott'm Forest": 'Nottingham Forest',
    'Vallecano': 'Rayo Vallecano',
    'Ein Frankfurt': 'Eintracht Frankfurt',
    "M'gladbach": 'Borussia M.Gladbach',
    'Leverkusen': 'Bayer Leverkusen',
    'Huesca': 'SD Huesca',
    'Celta': 'Celta Vigo',
    'Milan': 'AC Milan',
    'Man City': 'Manchester City',
    'Wolves': 'Wolverhampton Wanderers',
    'Espanol': 'Espanyol',
    'Sociedad': 'Real Sociedad',
    'Man United': 'Manchester United',
    'West Brom': 'West Bromwich Albion',
    'Betis': 'Real Betis',
    'Hertha': 'Hertha Berlin',
    'St Etienne': 'Saint-Etienne',
    'Heidenheim': 'FC Heidenheim',
    'Valladolid': 'Real Valladolid',
    'Hannover': 'Hannover 96',
    'Parma': 'Parma Calcio 1913'
}

# Apply the mapping to both 'home_team' and 'away_team' columns
odds_data['home_team'] = odds_data['home_team'].map(name_mapping).fillna(odds_data['home_team'])
odds_data['away_team'] = odds_data['away_team'].map(name_mapping).fillna(odds_data['away_team'])

# Show the updated DataFrame
print(odds_data[['home_team', 'away_team']])
# Out:
#                home_team       away_team
# 0      Manchester United       Leicester
# 1            Bournemouth         Cardiff
# 2                 Fulham  Crystal Palace
# 3           Huddersfield         Chelsea
# 4       Newcastle United       Tottenham
# ...                  ...             ...
# 10644           AC Milan           Genoa
# 10645               Roma        Juventus
# 10646             Verona      Fiorentina
# 10647        Salernitana        Atalanta
# 10648            Udinese          Napoli
#
# [10649 rows x 2 columns]

# %%
import pandas as pd

# Assuming odds_data and team_match_stats are your DataFrames
# Extract sets of teams from both home and away columns for each DataFrame
teams_in_odds = set(odds_data['home_team']).union(set(odds_data['away_team']))
teams_in_stats = set(team_match_stats['home_team']).union(set(team_match_stats['away_team']))

# Find teams in odds_data but not in team_match_stats
teams_in_odds_not_in_stats = teams_in_odds - teams_in_stats

# Find teams in team_match_stats but not in odds_data
teams_in_stats_not_in_odds = teams_in_stats - teams_in_odds

# Print the results
print("Teams in odds_data not in team_match_stats:", teams_in_odds_not_in_stats)
print("Teams in team_match_stats not in odds_data:", teams_in_stats_not_in_odds)
# Out:
# Teams in odds_data not in team_match_stats: set()
# Teams in team_match_stats not in odds_data: set()

# %%
# Ensure the date columns in both dataframes are of datetime type
team_match_stats['date'] = pd.to_datetime(team_match_stats['date'])
odds_data['date'] = pd.to_datetime(odds_data['date'])

# Perform the merge
merged_df = pd.merge(team_match_stats, odds_data[['date', 'home_team', 'away_team', 'B365H', 'B365D', 'B365A']],
                     on=['date', 'home_team', 'away_team'], how='left')

# Check the first few rows of the merged DataFrame to verify
print(merged_df.head())
# Out:
#   league_id  season_id  game_id       date  home_team_id  away_team_id  \
# 0         1       2018     9197 2018-08-10            89            75
# 1         5       2018    10643 2018-08-10           164           174
# 2         1       2018     9200 2018-08-11           219            80
# 3         1       2018     9198 2018-08-11            86            82
# 4         1       2018     9199 2018-08-11            90           220
#
#            home_team  away_team away_team_code home_team_code  ...  \
# 0  Manchester United  Leicester            LEI            MUN  ...
# 1          Marseille   Toulouse            TOU            MAR  ...
# 2       Huddersfield    Chelsea            CHE            HUD  ...
# 3   Newcastle United  Tottenham            TOT            NEW  ...
# 4            Watford   Brighton            BRI            WAT  ...
#
#    away_rolling_avg_deep_completions  home_rolling_avg_xG_diff  \
# 0                                6.8                  0.023119
# 1                                4.6                  0.984853
# 2                               12.8                 -0.650910
# 3                               11.0                 -0.092722
# 4                                2.4                 -0.449947
#
#    away_rolling_avg_xG_diff  home_rolling_avg_deep_completions_diff  \
# 0                  0.159467                                    3.88
# 1                 -0.337328                                    3.48
# 2                  0.786680                                   -2.40
# 3                 -0.293040                                    0.20
# 4                 -0.429467                                    0.32
#
#    away_rolling_avg_deep_completions_diff  home_rolling_avg_goals_diff  \
# 0                                    1.20                         0.68
# 1                                   -1.68                         1.12
# 2                                    9.24                        -0.56
# 3                                    3.20                         0.24
# 4                                   -3.52                        -1.28
#
#    away_rolling_avg_goals_diff  B365H  B365D  B365A
# 0                        -0.56   1.57    3.9   7.50
# 1                        -0.40   1.40    4.5   8.00
# 2                         0.36   6.50    4.0   1.61
# 3                         0.52   3.90    3.5   2.04
# 4                        -0.56   2.37    3.2   3.40
#
# [5 rows x 53 columns]

# %%
merged_df
# Out:
#       league_id  season_id  game_id       date  home_team_id  away_team_id  \
# 0             1       2018     9197 2018-08-10            89            75
# 1             5       2018    10643 2018-08-10           164           174
# 2             1       2018     9200 2018-08-11           219            80
# 3             1       2018     9198 2018-08-11            86            82
# 4             1       2018     9199 2018-08-11            90           220
# ...         ...        ...      ...        ...           ...           ...
# 10550         4       2023    23015 2024-05-05           152           154
# 10551         2       2023    22647 2024-05-06           264           107
# 10552         5       2023    23652 2024-05-06           160           178
# 10553         1       2023    22250 2024-05-06            78            89
# 10554         2       2023    22654 2024-05-06            99           105
#
#                home_team          away_team away_team_code home_team_code  \
# 0      Manchester United          Leicester            LEI            MUN
# 1              Marseille           Toulouse            TOU            MAR
# 2           Huddersfield            Chelsea            CHE            HUD
# 3       Newcastle United          Tottenham            TOT            NEW
# 4                Watford           Brighton            BRI            WAT
# ...                  ...                ...            ...            ...
# 10550         Celta Vigo         Villarreal            VIL            CEL
# 10551        Salernitana           Atalanta            ATA            SAL
# 10552              Lille               Lyon            LYO            LIL
# 10553     Crystal Palace  Manchester United            MUN            CRY
# 10554            Udinese             Napoli            NAP            UDI
#
#        ...  away_rolling_avg_deep_completions  home_rolling_avg_xG_diff  \
# 0      ...                                6.8                  0.023119
# 1      ...                                4.6                  0.984853
# 2      ...                               12.8                 -0.650910
# 3      ...                               11.0                 -0.092722
# 4      ...                                2.4                 -0.449947
# ...    ...                                ...                       ...
# 10550  ...                                7.6                 -0.390726
# 10551  ...                                8.8                 -1.435071
# 10552  ...                               11.8                  0.457897
# 10553  ...                               10.6                 -0.053460
# 10554  ...                                9.2                 -0.678307
#
#        away_rolling_avg_xG_diff  home_rolling_avg_deep_completions_diff  \
# 0                      0.159467                                    3.88
# 1                     -0.337328                                    3.48
# 2                      0.786680                                   -2.40
# 3                     -0.293040                                    0.20
# 4                     -0.429467                                    0.32
# ...                         ...                                     ...
# 10550                  0.658083                                    1.28
# 10551                 -0.455785                                   -4.20
# 10552                  0.273424                                    1.52
# 10553                 -1.131605                                   -2.28
# 10554                  0.607698                                   -5.80
#
#        away_rolling_avg_deep_completions_diff  home_rolling_avg_goals_diff  \
# 0                                        1.20                         0.68
# 1                                       -1.68                         1.12
# 2                                        9.24                        -0.56
# 3                                        3.20                         0.24
# 4                                       -3.52                        -1.28
# ...                                       ...                          ...
# 10550                                    1.56                        -0.56
# 10551                                    2.12                        -1.64
# 10552                                    1.04                         0.52
# 10553                                   -9.76                        -0.12
# 10554                                    4.32                        -0.64
#
#        away_rolling_avg_goals_diff  B365H  B365D  B365A
# 0                            -0.56   1.57   3.90   7.50
# 1                            -0.40   1.40   4.50   8.00
# 2                             0.36   6.50   4.00   1.61
# 3                             0.52   3.90   3.50   2.04
# 4                            -0.56   2.37   3.20   3.40
# ...                            ...    ...    ...    ...
# 10550                         1.16   2.30   3.60   2.88
# 10551                        -0.12   7.50   5.50   1.36
# 10552                         0.48   1.91   3.80   3.80
# 10553                        -0.04   2.38   3.75   2.80
# 10554                         0.24   3.75   3.60   1.95
#
# [10555 rows x 53 columns]

# %%
features = [column for column in merged_df.drop(columns=['league_id', 'season_id', 'game_id', 'home_team_id',
       'away_team_id', 'home_team', 'away_team', 'away_team_code',
       'home_team_code', 'away_points', 'away_expected_points', 'away_goals',
       'away_xg', 'away_np_xg', 'away_np_xg_difference', 'away_ppda',
       'away_deep_completions', 'home_points', 'home_expected_points',
       'home_goals', 'home_xg', 'home_np_xg', 'home_np_xg_difference',
       'home_ppda', 'home_deep_completions', 'result', 'season_start', 'date']).columns]

# %%
features
# Out:
# ['home_rolling_avg_goals_allowed',
#  'away_rolling_avg_goals_allowed',
#  'home_rolling_avg_xG_allowed',
#  'away_rolling_avg_xG_allowed',
#  'home_rolling_avg_ppda_allowed',
#  'away_rolling_avg_ppda_allowed',
#  'home_rolling_avg_deep_completions_allowed',
#  'away_rolling_avg_deep_completions_allowed',
#  'home_rolling_avg_goals',
#  'away_rolling_avg_goals',
#  'home_rolling_avg_xG',
#  'away_rolling_avg_xG',
#  'home_rolling_avg_ppda',
#  'away_rolling_avg_ppda',
#  'home_rolling_avg_deep_completions',
#  'away_rolling_avg_deep_completions',
#  'home_rolling_avg_xG_diff',
#  'away_rolling_avg_xG_diff',
#  'home_rolling_avg_deep_completions_diff',
#  'away_rolling_avg_deep_completions_diff',
#  'home_rolling_avg_goals_diff',
#  'away_rolling_avg_goals_diff',
#  'B365H',
#  'B365D',
#  'B365A']

# %%
# Convert 'season_start' to integer
merged_df['season_start'] = merged_df['season_start'].astype(int)

# Now, split the data into train and test sets
train_data = merged_df[merged_df['season_start'] <= 2022]
test_data = merged_df[merged_df['season_start'] == 2023]

# Assuming 'features' and 'result' are correctly defined in your context
X_train = train_data[features]
y_train = train_data['result']
X_test = test_data[features]
y_test = test_data['result']

# %%
# Train a Random Forest model
clf = RandomForestClassifier(random_state=1)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Make predictions
predictions = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
accuracy
# Out:
# 0.5372208436724566

# %%
from sklearn.metrics import classification_report

# Generate a classification report
report = classification_report(y_test, predictions, target_names=['Class 1', 'Class 2', 'Class 3'])  # Adjust class names accordingly
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.51      0.61      0.56       483
#      Class 2       0.36      0.07      0.12       431
#      Class 3       0.57      0.77      0.66       698
#
#     accuracy                           0.54      1612
#    macro avg       0.48      0.49      0.44      1612
# weighted avg       0.50      0.54      0.48      1612

# %%
# This is applicable only if your model supports .coef_ or .feature_importances_
if hasattr(clf, 'coef_'):
    print("Coefficients:\n", clf.coef_)
elif hasattr(clf, 'feature_importances_'):
    importances = pd.DataFrame({'feature': X_train.columns, 'importance': clf.feature_importances_})
    importances.sort_values('importance', ascending=False, inplace=True)
    print(importances)
# Out:
#                                       feature  importance
# 22                                      B365H    0.062422
# 24                                      B365A    0.059041
# 19     away_rolling_avg_deep_completions_diff    0.047786
# 17                   away_rolling_avg_xG_diff    0.047205
# 18     home_rolling_avg_deep_completions_diff    0.045625
# 16                   home_rolling_avg_xG_diff    0.045090
# 11                        away_rolling_avg_xG    0.043615
# 4               home_rolling_avg_ppda_allowed    0.043426
# 13                      away_rolling_avg_ppda    0.042756
# 5               away_rolling_avg_ppda_allowed    0.042663
# 10                        home_rolling_avg_xG    0.042437
# 2                 home_rolling_avg_xG_allowed    0.042147
# 12                      home_rolling_avg_ppda    0.041596
# 3                 away_rolling_avg_xG_allowed    0.041047
# 20                home_rolling_avg_goals_diff    0.039373
# 21                away_rolling_avg_goals_diff    0.038114
# 15          away_rolling_avg_deep_completions    0.036648
# 14          home_rolling_avg_deep_completions    0.035338
# 6   home_rolling_avg_deep_completions_allowed    0.035224
# 7   away_rolling_avg_deep_completions_allowed    0.033607
# 23                                      B365D    0.031800
# 0              home_rolling_avg_goals_allowed    0.026155
# 8                      home_rolling_avg_goals    0.025995
# 9                      away_rolling_avg_goals    0.025606
# 1              away_rolling_avg_goals_allowed    0.025281

# %%
schedule = understat.read_schedule()
schedule.head()
# Out:
#                                                                  league_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                   1
#                           2017-08-12 Brighton-Manchester City            1
#                           2017-08-12 Chelsea-Burnley                     1
#                           2017-08-12 Crystal Palace-Huddersfield         1
#                           2017-08-12 Everton-Stoke                       1
#
#                                                                   season_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                 2017
#                           2017-08-12 Brighton-Manchester City          2017
#                           2017-08-12 Chelsea-Burnley                   2017
#                           2017-08-12 Crystal Palace-Huddersfield       2017
#                           2017-08-12 Everton-Stoke                     2017
#
#                                                                   game_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester               7119
#                           2017-08-12 Brighton-Manchester City        7126
#                           2017-08-12 Chelsea-Burnley                 7123
#                           2017-08-12 Crystal Palace-Huddersfield     7124
#                           2017-08-12 Everton-Stoke                   7125
#
#                                                                                 date  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester           2017-08-11 19:45:00
#                           2017-08-12 Brighton-Manchester City    2017-08-12 17:30:00
#                           2017-08-12 Chelsea-Burnley             2017-08-12 15:00:00
#                           2017-08-12 Crystal Palace-Huddersfield 2017-08-12 15:00:00
#                           2017-08-12 Everton-Stoke               2017-08-12 15:00:00
#
#                                                                   home_team_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                      83
#                           2017-08-12 Brighton-Manchester City              220
#                           2017-08-12 Chelsea-Burnley                        80
#                           2017-08-12 Crystal Palace-Huddersfield            78
#                           2017-08-12 Everton-Stoke                          72
#
#                                                                   away_team_id  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                      75
#                           2017-08-12 Brighton-Manchester City               88
#                           2017-08-12 Chelsea-Burnley                        92
#                           2017-08-12 Crystal Palace-Huddersfield           219
#                           2017-08-12 Everton-Stoke                          85
#
#                                                                        home_team  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                   Arsenal
#                           2017-08-12 Brighton-Manchester City           Brighton
#                           2017-08-12 Chelsea-Burnley                     Chelsea
#                           2017-08-12 Crystal Palace-Huddersfield  Crystal Palace
#                           2017-08-12 Everton-Stoke                       Everton
#
#                                                                         away_team  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                  Leicester
#                           2017-08-12 Brighton-Manchester City     Manchester City
#                           2017-08-12 Chelsea-Burnley                      Burnley
#                           2017-08-12 Crystal Palace-Huddersfield     Huddersfield
#                           2017-08-12 Everton-Stoke                          Stoke
#
#                                                                  away_team_code  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                      LEI
#                           2017-08-12 Brighton-Manchester City               MCI
#                           2017-08-12 Chelsea-Burnley                        BUR
#                           2017-08-12 Crystal Palace-Huddersfield            HUD
#                           2017-08-12 Everton-Stoke                          STO
#
#                                                                  home_team_code  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                      ARS
#                           2017-08-12 Brighton-Manchester City               BRI
#                           2017-08-12 Chelsea-Burnley                        CHE
#                           2017-08-12 Crystal Palace-Huddersfield            CRY
#                           2017-08-12 Everton-Stoke                          EVE
#
#                                                                   home_goals  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                     4
#                           2017-08-12 Brighton-Manchester City              0
#                           2017-08-12 Chelsea-Burnley                       2
#                           2017-08-12 Crystal Palace-Huddersfield           0
#                           2017-08-12 Everton-Stoke                         1
#
#                                                                   away_goals  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester
\
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                 True
#                           2017-08-12 Brighton-Manchester City          True
#                           2017-08-12 Chelsea-Burnley                   True
#                           2017-08-12 Crystal Palace-Huddersfield       True
#                           2017-08-12 Everton-Stoke                     True
# ...                                                                     ...
# ITA-Serie A        2324   2024-05-26 Genoa-Bologna                    False
#                           2024-05-26 Juventus-Monza                   False
#                           2024-05-26 Lazio-Sassuolo                   False
#                           2024-05-26 Napoli-Lecce                     False
#                           2024-05-26 Verona-Inter                     False
#
#                                                                   has_data  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester                True
#                           2017-08-12 Brighton-Manchester City         True
#                           2017-08-12 Chelsea-Burnley                  True
#                           2017-08-12 Crystal Palace-Huddersfield      True
#                           2017-08-12 Everton-Stoke                    True
# ...                                                                    ...
# ITA-Serie A        2324   2024-05-26 Genoa-Bologna                   False
#                           2024-05-26 Juventus-Monza                  False
#                           2024-05-26 Lazio-Sassuolo                  False
#                           2024-05-26 Napoli-Lecce                    False
#                           2024-05-26 Verona-Inter                    False
#
#                                                                                                 url  \
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester             https://understat.com/match/7119
#                           2017-08-12 Brighton-Manchester City      https://understat.com/match/7126
#                           2017-08-12 Chelsea-Burnley               https://understat.com/match/7123
#                           2017-08-12 Crystal Palace-Huddersfield   https://understat.com/match/7124
#                           2017-08-12 Everton-Stoke                 https://understat.com/match/7125
# ...                                                                                             ...
# ITA-Serie A        2324   2024-05-26 Genoa-Bologna                https://understat.com/match/22683
#                           2024-05-26 Juventus-Monza               https://understat.com/match/22680
#                           2024-05-26 Lazio-Sassuolo               https://understat.com/match/22681
#                           2024-05-26 Napoli-Lecce                 https://understat.com/match/22684
#                           2024-05-26 Verona-Inter                 https://understat.com/match/22679
#
#                                                                         Date
# league             season game
# ENG-Premier League 1718   2017-08-11 Arsenal-Leicester            2017-08-11
#                           2017-08-12 Brighton-Manchester City     2017-08-12
#                           2017-08-12 Chelsea-Burnley              2017-08-12
#                           2017-08-12 Crystal Palace-Huddersfield  2017-08-12
#                           2017-08-12 Everton-Stoke                2017-08-12
# ...                                                                      ...
# ITA-Serie A        2324   2024-05-26 Genoa-Bologna                2024-05-26
#                           2024-05-26 Juventus-Monza               2024-05-26
#                           2024-05-26 Lazio-Sassuolo               2024-05-26
#                           2024-05-26 Napoli-Lecce                 2024-05-26
#                           2024-05-26 Verona-Inter                 2024-05-26
#
# [12709 rows x 18 columns]

# %%
# Convert 'Date' column to datetime if not already
schedule['Date'] = pd.to_datetime(schedule['Date'])

# Define the date range
start_date = pd.Timestamp('2024-05-10')
end_date = pd.Timestamp('2024-05-14')

# Filter the DataFrame to include only the dates within the specified range
filtered_schedule = schedule[(schedule['Date'] >= start_date) & (schedule['Date'] <= end_date)]

filtered_schedule['Game Matchup'] = filtered_schedule['home_team'] + ' vs ' + filtered_schedule['away_team']

# Print the DataFrame to verify that the new column has been added correctly
print(filtered_schedule[['home_team', 'away_team', 'Game Matchup']])
# Out:
#                                                                                             home_team  \
# league             season game
# ENG-Premier League 2324   2024-05-11 Bournemouth-Brentford                                Bournemouth
#                           2024-05-11 Everton-Sheffield United                                 Everton
#                           2024-05-11 Freiburg-FC Heidenheim                                    Freiburg vs FC Heidenheim
#                           2024-05-11 Mainz 05-Borussia Dortmund                            Mainz 05 vs Borussia Dortmund
#                           2024-05-11 RasenBallsport Leipzig-Werder Bremen        RasenBallsport Leipzig vs Werder Bremen
#                           2024-05-12 Bayern Munich-Wolfsburg                                  Bayern Munich vs Wolfsburg
#                           2024-05-12 Bochum-Bayer Leverkusen                                  Bochum vs Bayer Leverkusen
#                           2024-05-12 Darmstadt-Hoffenheim                                        Darmstadt vs Hoffenheim
# ITA-Serie A        2324   2024-05-10 Frosinone-Inter                                                  Frosinone vs Inter
#                           2024-05-11 AC Milan-Cagliari                                              AC Milan vs Cagliari
#                           2024-05-11 Napoli-Bologna                                                    Napoli vs Bologna
#                           2024-05-12 Atalanta-Roma                                                      Atalanta vs Roma
#                           2024-05-12 Genoa-Sassuolo                                                    Genoa vs Sassuolo
#                           2024-05-12 Juventus-Salernitana                                        Juventus vs Salernitana
#                           2024-05-12 Lazio-Empoli                                                        Lazio vs Empoli
#                           2024-05-12 Verona-Torino                                                      Verona vs Torino
#                           2024-05-13 Fiorentina-Monza                                                Fiorentina vs Monza
#                           2024-05-13 Lecce-Udinese                                                      Lecce vs Udinese
# C:\Users\jbuck\AppData\Local\Temp\ipykernel_10988\533074640.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_schedule['Game Matchup'] = filtered_schedule['home_team'] + ' vs ' + filtered_schedule['away_team']

# %%
features
# Out:
# ['home_rolling_avg_goals_allowed',
#  'away_rolling_avg_goals_allowed',
#  'home_rolling_avg_xG_allowed',
#  'away_rolling_avg_xG_allowed',
#  'home_rolling_avg_ppda_allowed',
#  'away_rolling_avg_ppda_allowed',
#  'home_rolling_avg_deep_completions_allowed',
#  'away_rolling_avg_deep_completions_allowed',
#  'home_rolling_avg_goals',
#  'away_rolling_avg_goals',
#  'home_rolling_avg_xG',
#  'away_rolling_avg_xG',
#  'home_rolling_avg_ppda',
#  'away_rolling_avg_ppda',
#  'home_rolling_avg_deep_completions',
#  'away_rolling_avg_deep_completions',
#  'home_rolling_avg_xG_diff',
#  'away_rolling_avg_xG_diff',
#  'home_rolling_avg_deep_completions_diff',
#  'away_rolling_avg_deep_completions_diff',
#  'home_rolling_avg_goals_diff',
#  'away_rolling_avg_goals_diff',
#  'B365H',
#  'B365D',
#  'B365A']

# %%
import pandas as pd

# Assuming 'team_match_stats', 'filtered_schedule', 'clf', and 'X_train' are already defined and loaded

results_df = pd.DataFrame(columns=['Game Matchup', 'Probability Home Win', 'Probability Draw', 'Probability Away Win'])

for index, match in filtered_schedule.iterrows():
    home_team = match['home_team']
    away_team = match['away_team']

    home_columns = ['home_rolling_avg_goals', 'home_rolling_avg_xG', 'home_rolling_avg_ppda', 'home_rolling_avg_deep_completions',
                    'home_rolling_avg_goals_allowed', 'home_rolling_avg_xG_allowed', 'home_rolling_avg_ppda_allowed',
                    'home_rolling_avg_deep_completions_allowed', 'home_rolling_avg_xG_diff', 'home_rolling_avg_deep_completions_diff', 'home_rolling_avg_goals_diff']
    away_columns = ['away_rolling_avg_goals', 'away_rolling_avg_xG', 'away_rolling_avg_ppda', 'away_rolling_avg_deep_completions',
                    'away_rolling_avg_goals_allowed', 'away_rolling_avg_xG_allowed', 'away_rolling_avg_ppda_allowed',
                    'away_rolling_avg_deep_completions_allowed', 'away_rolling_avg_xG_diff', 'away_rolling_avg_deep_completions_diff', 'away_rolling_avg_goals_diff' ]

    home_stats = team_match_stats[(team_match_stats['home_team'] == home_team) & (team_match_stats['season_start'] == 2023)][home_columns].mean()
    away_stats = team_match_stats[(team_match_stats['away_team'] == away_team) & (team_match_stats['season_start'] == 2023)][away_columns].mean()

    data = {
        'home_rolling_avg_goals': [home_stats['home_rolling_avg_goals']],
        'away_rolling_avg_goals': [away_stats['away_rolling_avg_goals']],
        'home_rolling_avg_xG': [home_stats['home_rolling_avg_xG']],
        'away_rolling_avg_xG': [away_stats['away_rolling_avg_xG']],
        'home_rolling_avg_ppda': [home_stats['home_rolling_avg_ppda']],
        'away_rolling_avg_ppda': [away_stats['away_rolling_avg_ppda']],
        'home_rolling_avg_deep_completions': [home_stats['home_rolling_avg_deep_completions']],
        'away_rolling_avg_deep_completions': [away_stats['away_rolling_avg_deep_completions']],
        'home_rolling_avg_goals_allowed': [home_stats['home_rolling_avg_goals_allowed']],
        'away_rolling_avg_goals_allowed': [away_stats['away_rolling_avg_goals_allowed']],
        'home_rolling_avg_xG_allowed': [home_stats['home_rolling_avg_xG_allowed']],
        'away_rolling_avg_xG_allowed': [away_stats['away_rolling_avg_xG_allowed']],
        'home_rolling_avg_ppda_allowed': [home_stats['home_rolling_avg_ppda_allowed']],
        'away_rolling_avg_ppda_allowed': [away_stats['away_rolling_avg_ppda_allowed']],
        'home_rolling_avg_deep_completions_allowed': [home_stats['home_rolling_avg_deep_completions_allowed']],
        'away_rolling_avg_deep_completions_allowed': [away_stats['away_rolling_avg_deep_completions_allowed']],
        'home_rolling_avg_xG_diff': [home_stats['home_rolling_avg_xG_diff']],
        'away_rolling_avg_xG_diff': [away_stats['away_rolling_avg_xG_diff']],
        'home_rolling_avg_deep_completions_diff': [home_stats['home_rolling_avg_deep_completions_diff']],
        'away_rolling_avg_deep_completions_diff': [away_stats['away_rolling_avg_deep_completions_diff']],
        'home_rolling_avg_goals_diff': [home_stats['home_rolling_avg_goals_diff']],
        'away_rolling_avg_goals_diff': [away_stats['away_rolling_avg_goals_diff']],



    }

    match_df = pd.DataFrame(data)
    for column in X_train.columns:
        if column not in match_df.columns:
            match_df[column] = 0

    match_df = match_df[X_train.columns]

    probabilities = clf.predict_proba(match_df)

    current_results = pd.DataFrame({
        'Game Matchup': [match['Game Matchup']],
        'Probability Home Win': [probabilities[0][2]],
        'Probability Draw': [probabilities[0][1]],
        'Probability Away Win': [probabilities[0][0]]
    })

    results_df = pd.concat([results_df, current_results], ignore_index=True)

# Convert probabilities to percentages
results_df['Probability Home Win'] = (results_df['Probability Home Win'] * 100).round(2)
results_df['Probability Draw'] = (results_df['Probability Draw'] * 100).round(2)
results_df['Probability Away Win'] = (results_df['Probability Away Win'] * 100).round(2)

# Determine the highest probability and assign the predicted result using np.select()
import numpy as np

conditions = [
    (results_df['Probability Home Win'] > results_df['Probability Away Win']) & (results_df['Probability Home Win'] > results_df['Probability Draw']),
    (results_df['Probability Away Win'] > results_df['Probability Home Win']) & (results_df['Probability Away Win'] > results_df['Probability Draw']),
    (results_df['Probability Draw'] > results_df['Probability Home Win']) & (results_df['Probability Draw'] > results_df['Probability Away Win'])
]

choices = ['Home Win', 'Away Win', 'Draw']
results_df['Predicted Result'] = np.select(conditions, choices, default='Draw')  # Default to 'Draw' if probabilities are equal

results_df
# Out:
# C:\Users\jbuck\AppData\Local\Temp\ipykernel_10988\479378739.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, current_results], ignore_index=True)
#                                   Game Matchup  Probability Home Win  \
# 0                     Bournemouth vs Brentford                  44.0
# 1                  Everton vs Sheffield United                  44.0
# 2                    Fulham vs Manchester City                  35.0
# 3                 Newcastle United vs Brighton                  43.0
# 4                 Nottingham Forest vs Chelsea                  29.0
# 5                         Tottenham vs Burnley                  51.0
# 6                            West Ham vs Luton                  35.0
# 7    Wolverhampton Wanderers vs Crystal Palace                  44.0
# 8                 Manchester United vs Arsenal                  34.0
# 9                     Aston Villa vs Liverpool                  35.0
# 10                Tottenham vs Manchester City                  37.0
# 11                            Alaves vs Girona                  34.0
# 12                    Athletic Club vs Osasuna                  52.0
# 13                      Granada vs Real Madrid                  24.0
# 14                      Mallorca vs Las Palmas                  37.0
# 15                       Villarreal vs Sevilla                  43.0
# 16               Atletico Madrid vs Celta Vigo                  51.0
# 17                             Cadiz vs Getafe                  34.0
# 18                       Real Betis vs Almeria                  51.0
# 19                  Valencia vs Rayo Vallecano                  33.0
# 20                  Barcelona vs Real Sociedad                  48.0
# 21                        Girona vs Villarreal                  40.0
# 22                         Osasuna vs Mallorca                  35.0
# 23                       Real Madrid vs Alaves                  46.0
# 24                              Brest vs Reims                  43.0
# 25                            Nice vs Le Havre                  49.0
# 26                       Clermont Foot vs Lyon                  31.0
# 27                        Marseille vs Lorient                  48.0
# 28                       Montpellier vs Monaco                  34.0
# 29                             Nantes vs Lille                  35.0
# 30             Paris Saint Germain vs Toulouse                  48.0
# 31                              Rennes vs Lens                  47.0
# 32                          Strasbourg vs Metz                  50.0
# 33                   Augsburg vs VfB Stuttgart                  28.0
# 34  Borussia M.Gladbach vs Eintracht Frankfurt                  38.0
# 35                  FC Cologne vs Union Berlin                  31.0
# 36                   Freiburg vs FC Heidenheim                  37.0
# 37               Mainz 05 vs Borussia Dortmund                  27.0
# 38     RasenBallsport Leipzig vs Werder Bremen                  50.0
# 39                  Bayern Munich vs Wolfsburg                  52.0
# 40                  Bochum vs Bayer Leverkusen                  28.0
# 41                     Darmstadt vs Hoffenheim                  42.0
# 42                          Frosinone vs Inter                  32.0
# 43                        AC Milan vs Cagliari                  42.0
# 44                           Napoli vs Bologna                  49.0
# 45                            Atalanta vs Roma                  46.0
# 46                           Genoa vs Sassuolo                  41.0
# 47                     Juventus vs Salernitana                  49.0
# 48                             Lazio vs Empoli                  51.0
# 49                            Verona vs Torino                  39.0
# 50                         Fiorentina vs Monza                  47.0
# 51                            Lecce vs Udinese                  43.0
#
#     Probability Draw  Probability Away Win Predicted Result
# 0               35.0                  21.0         Home Win
# 1               24.0                  32.0         Home Win
# 2               26.0                  39.0         Away Win
# 3               30.0                  27.0         Home Win
# 4               28.0                  43.0         Away Win
# 5               25.0                  24.0         Home Win
# 6               43.0                  22.0             Draw
# 7               28.0                  28.0         Home Win
# 8               32.0                  34.0             Draw
# 9               34.0                  31.0         Home Win
# 10              32.0                  31.0         Home Win
# 11              27.0                  39.0         Away Win
# 12              25.0                  23.0         Home Win
# 13              26.0                  50.0         Away Win
# 14              32.0                  31.0         Home Win
# 15              23.0                  34.0         Home Win
# 16              29.0                  20.0         Home Win
# 17              27.0                  39.0         Away Win
# 18              28.0                  21.0         Home Win
# 19              32.0                  35.0         Away Win
# 20              29.0                  23.0         Home Win
# 21              27.0                  33.0         Home Win
# 22              38.0                  27.0             Draw
# 23              35.0                  19.0         Home Win
# 24              32.0                  25.0         Home Win
# 25              26.0                  25.0         Home Win
# 26              27.0                  42.0         Away Win
# 27              28.0                  24.0         Home Win
# 28              21.0                  45.0         Away Win
# 29              26.0                  39.0         Away Win
# 30              35.0                  17.0         Home Win
# 31              22.0                  31.0         Home Win
# 32              24.0                  26.0         Home Win
# 33              28.0                  44.0         Away Win
# 34              28.0                  34.0         Home Win
# 35              31.0                  38.0         Away Win
# 36              35.0                  28.0         Home Win
# 37              30.0                  43.0         Away Win
# 38              32.0                  18.0         Home Win
# 39              24.0                  24.0         Home Win
# 40              29.0                  43.0         Away Win
# 41              25.0                  33.0         Home Win
# 42              23.0                  45.0         Away Win
# 43              28.0                  30.0         Home Win
# 44              24.0                  27.0         Home Win
# 45              29.0                  25.0         Home Win
# 46              35.0                  24.0         Home Win
# 47              27.0                  24.0         Home Win
# 48              26.0                  23.0         Home Win
# 49              23.0                  38.0         Home Win
# 50              31.0                  22.0         Home Win
# 51              27.0                  30.0         Home Win

# %%
results_df.to_csv('Weekend_Of_May_10th_Results_Predictions_fun.csv', index=False)
# Cell 1: Check current branch
# !git branch

# Cell 2: Add CSV file to Git
# !git add Weekend_Of_May_10th_Results_Predictions_fun.csv

# Cell 3: Commit changes
# !git commit -m "Added corresponding CSV data"

# Cell 4: Push to GitHub (assuming the current branch is 'main')
# !git push origin main
# Out:
# * main
# [main 414aa4c] Added corresponding CSV data
#  1 file changed, 53 insertions(+)
#  create mode 100644 Weekend_Of_May_10th_Results_Predictions_fun.csv
# To https://github.com/Jbuck1016/Predicting-Matches
#    f24b674..414aa4c  main -> main

# %%
# !git add Predicting_Match_Results_Model.ipynb

# Cell 3: Commit changes
# !git commit -m "Added Jupyter notebook"

# Cell 4: Push to GitHub
# !git push origin main
# Out:
# warning: in the working copy of 'Predicting_Match_Results_Model.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 7199fe6] Added Jupyter notebook
#  1 file changed, 4466 insertions(+)
#  create mode 100644 Predicting_Match_Results_Model.ipynb
# To https://github.com/Jbuck1016/Predicting-Matches
#    27fb21b..7199fe6  main -> main

# %%
import pandas as pd

# URLs of the CSV files
urls = [
    "https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/Bundesliga_fbref_poss_stats.csv",
    "https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/EPL_fbref_poss_stats.csv",
    "https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/Ligue_Une_fbref_poss_stats.csv",
    "https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/Serie_A_fbref_poss_stats.csv",
    "https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/la_liga_fbref_poss_stats.csv"
]

# Load each CSV file into a DataFrame and store them in a list
dataframes = [pd.read_csv(url) for url in urls]

# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)
# Drop rows where the 'round' column contains the word 'round'
combined_df = combined_df[~combined_df['round'].str.contains('round', case=False, na=False)]


# Display the combined DataFrame
print(combined_df.head())  # Shows the first few rows of the combined DataFrame
# Out:
#   league  season      team                                game        date  \
# 1    NaN    1718  Augsburg    2017-08-19 Hamburger SV-Augsburg  2017-08-19
# 2    NaN    1718  Augsburg      2017-08-26 Augsburg-M'Gladbach  2017-08-26
# 3    NaN    1718  Augsburg            2017-09-09 Augsburg-Köln  2017-09-09
# 4    NaN    1718  Augsburg  2017-09-16 Eint Frankfurt-Augsburg  2017-09-16
# 5    NaN    1718  Augsburg      2017-09-19 Augsburg-RB Leipzig  2017-09-19
#
#          round  day venue result GF  ... Carries_PrgDist Carries_PrgC  \
# 1  Matchweek 1  Sat  Away      L  0  ...           960.0         16.0
# 2  Matchweek 2  Sat  Home      D  2  ...           763.0         19.0
# 3  Matchweek 3  Sat  Home      W  3  ...           712.0         20.0
# 4  Matchweek 4  Sat  Away      W  2  ...           515.0         12.0
# 5  Matchweek 5  Tue  Home      W  1  ...           531.0         13.0
#
#    Carries_1/3  Carries_CPA  Carries_Mis  Carries_Dis  Receiving_Rec  \
# 1         15.0          2.0         12.0          9.0          414.0
# 2         10.0          5.0          7.0          5.0          367.0
# 3         12.0          2.0         15.0          8.0          182.0
# 4         11.0          4.0         14.0          6.0          202.0
# 5         12.0          3.0         17.0          5.0          215.0
#
#    Receiving_PrgR      time                                       match_report
# 1            40.0  15:30:00  /en/matches/f65cd7dc/Hamburger-SV-Augsburg-Aug...
# 2            53.0  15:30:00  /en/matches/3d33cbcd/Augsburg-Monchengladbach-...
# 3            21.0  15:30:00  /en/matches/7e929ab2/Augsburg-Koln-September-9...
# 4            20.0  15:30:00  /en/matches/a357fa5b/Eintracht-Frankfurt-Augsb...
# 5            18.0  20:30:00  /en/matches/19965925/Augsburg-RB-Leipzig-Septe...
#
# [5 rows x 37 columns]

# %%
combined_df.columns
# Out:
# Index(['league', 'season', 'team', 'game', 'date', 'round', 'day', 'venue',
#        'result', 'GF', 'GA', 'opponent', 'Poss', 'Touches_Touches',
#        'Touches_Def Pen', 'Touches_Def 3rd', 'Touches_Mid 3rd',
#        'Touches_Att 3rd', 'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att',
#        'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%',
#        'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC',
#        'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis',
#        'Receiving_Rec', 'Receiving_PrgR', 'time', 'match_report'],
#       dtype='object')

# %%
import pandas as pd

# Assuming 'combined_df' is already your loaded DataFrame with the necessary columns

# Define a function that assigns home and away teams based on the venue
def assign_teams(row):
    if row['venue'] == 'Home':
        home_team = row['team']
        away_team = row['opponent']
    else:
        home_team = row['opponent']
        away_team = row['team']
    return pd.Series([home_team, away_team])

# Apply the function along the rows (axis=1)
combined_df[['home_team', 'away_team']] = combined_df.apply(assign_teams, axis=1)

# Print the DataFrame to verify the new columns
print(combined_df[['league', 'season', 'date', 'home_team', 'away_team', 'venue', 'result', 'GF', 'GA']])
# Out:
#             league  season        date       home_team        away_team venue  \
# 1              NaN    1718  2017-08-19    Hamburger SV         Augsburg  Away
# 2              NaN    1718  2017-08-26        Augsburg       M'Gladbach  Home
# 3              NaN    1718  2017-09-09        Augsburg             Köln  Home
# 4              NaN    1718  2017-09-16  Eint Frankfurt         Augsburg  Away
# 5              NaN    1718  2017-09-19        Augsburg       RB Leipzig  Home
# ...            ...     ...         ...             ...              ...   ...
# 25356  ESP-La Liga    2324  2024-02-23   Real Sociedad       Villarreal  Away
# 25357  ESP-La Liga    2324  2024-03-03      Villarreal          Granada  Home
# 25358  ESP-La Liga    2324  2024-03-10           Betis       Villarreal  Away
# 25359  ESP-La Liga    2324  2024-03-17      Villarreal         Valencia  Home
# 25360  ESP-La Liga    2324  2024-04-01      Villarreal  Atlético Madrid  Home
#
#       result GF GA
# 1          L  0  1
# 2          D  2  2
# 3          W  3  0
# 4          W  2  1
# 5          W  1  0
# ...      ... .. ..
# 25356      W  3  1
# 25357      W  5  1
# 25358      W  3  2
# 25359      W  1  0
# 25360      L  1  2
#
# [24938 rows x 9 columns]

# %%
import pandas as pd

# URL of the CSV file
url = 'https://raw.githubusercontent.com/Jbuck1016/Predicting-Matches/main/big_5_shot_stats.csv'

# Load the CSV file into a DataFrame
shots_df = pd.read_csv(url)


# Select only the necessary columns from shots_df
shots_df = shots_df[['date', 'home_team', 'away_team', 'Shots', 'Expected Goals Minus Goals']]

# Merge the DataFrames on the date, home_team, and away_team
combined_df = combined_df.merge(shots_df, on=['date', 'home_team', 'away_team'], how='left')

# Display the first few rows to confirm the merge
print(combined_df.head())
# Out:
#   league  season      team                              game        date  \
# 0    NaN    1718  Augsburg  2017-08-19 Hamburger SV-Augsburg  2017-08-19
# 1    NaN    1718  Augsburg  2017-08-19 Hamburger SV-Augsburg  2017-08-19
# 2    NaN    1718  Augsburg    2017-08-26 Augsburg-M'Gladbach  2017-08-26
# 3    NaN    1718  Augsburg    2017-08-26 Augsburg-M'Gladbach  2017-08-26
# 4    NaN    1718  Augsburg          2017-09-09 Augsburg-Köln  2017-09-09
#
#          round  day venue result GF  ... Carries_Mis Carries_Dis  \
# 0  Matchweek 1  Sat  Away      L  0  ...        12.0         9.0
# 1  Matchweek 1  Sat  Away      L  0  ...        12.0         9.0
# 2  Matchweek 2  Sat  Home      D  2  ...         7.0         5.0
# 3  Matchweek 2  Sat  Home      D  2  ...         7.0         5.0
# 4  Matchweek 3  Sat  Home      W  3  ...        15.0         8.0
#
#    Receiving_Rec  Receiving_PrgR      time  \
# 0          414.0            40.0  15:30:00
# 1          414.0            40.0  15:30:00
# 2          367.0            53.0  15:30:00
# 3          367.0            53.0  15:30:00
# 4          182.0            21.0  15:30:00
#
#                                         match_report     home_team  \
# 0  /en/matches/f65cd7dc/Hamburger-SV-Augsburg-Aug...  Hamburger SV
# 1  /en/matches/f65cd7dc/Hamburger-SV-Augsburg-Aug...  Hamburger SV
# 2  /en/matches/3d33cbcd/Augsburg-Monchengladbach-...      Augsburg
# 3  /en/matches/3d33cbcd/Augsburg-Monchengladbach-...      Augsburg
# 4  /en/matches/7e929ab2/Augsburg-Koln-September-9...      Augsburg
#
#     away_team  Shots  Expected Goals Minus Goals
# 0    Augsburg   14.0                        -0.8
# 1    Augsburg   11.0                         0.5
# 2  M'Gladbach   24.0                        -0.7
# 3  M'Gladbach   16.0                         0.7
# 4        Köln    9.0                         0.7
#
# [5 rows x 41 columns]

# %%
import pandas as pd

# Define the function to enhance the game stats in the DataFrame
def enhance_game_stats(combined_df):
    # Initialize new columns
    combined_df['Home_Touches_Att 3rd'] = None
    combined_df['Home_Touches_Att Pen'] = None
    combined_df['Away_Touches_Att 3rd'] = None
    combined_df['Away_Touches_Att Pen'] = None
    
    # Initialize columns for Shots and Expected Goals Minus Goals
    combined_df['Home_Shots'] = None
    combined_df['Away_Shots'] = None
    combined_df['Home_Expected Goals Minus Goals'] = None
    combined_df['Away_Expected Goals Minus Goals'] = None

    # For each unique game, populate the home and away stats across both rows
    for game in combined_df['game'].unique():
        # Subset DataFrame for the specific game
        game_df = combined_df[combined_df['game'] == game]
        
        # Assuming there are always exactly two rows per game
        for index, row in game_df.iterrows():
            if row['venue'] == 'Home':
                home_stats = row
                home_index = index
            else:
                away_stats = row
                away_index = index
        
        # Apply home and away stats to both rows
        combined_df.loc[game_df.index, 'Home_Touches_Att 3rd'] = home_stats['Touches_Att 3rd']
        combined_df.loc[game_df.index, 'Home_Touches_Att Pen'] = home_stats['Touches_Att Pen']
        combined_df.loc[game_df.index, 'Away_Touches_Att 3rd'] = away_stats['Touches_Att 3rd']
        combined_df.loc[game_df.index, 'Away_Touches_Att Pen'] = away_stats['Touches_Att Pen']

        # Apply Shots and Expected Goals Minus Goals
        combined_df.loc[game_df.index, 'Home_Shots'] = home_stats['Shots']
        combined_df.loc[game_df.index, 'Away_Shots'] = away_stats['Shots']
        combined_df.loc[game_df.index, 'Home_Expected Goals Minus Goals'] = home_stats['Expected Goals Minus Goals']
        combined_df.loc[game_df.index, 'Away_Expected Goals Minus Goals'] = away_stats['Expected Goals Minus Goals']

    return combined_df

# Assuming combined_df is already defined and contains your data
combined_df = enhance_game_stats(combined_df)

# You can now use enhanced_combined_df for further analysis or export
print(combined_df)
# Out:
#             league  season        team                                   game  \
# 0              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 1              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 2              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 3              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 4              NaN    1718    Augsburg               2017-09-09 Augsburg-Köln
# ...            ...     ...         ...                                    ...
# 49604  ESP-La Liga    2324  Villarreal            2024-03-10 Betis-Villarreal
# 49605  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49606  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49607  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
# 49608  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
#
#              date         round  day venue result GF  ... Shots  \
# 0      2017-08-19   Matchweek 1  Sat  Away      L  0  ...  14.0
# 1      2017-08-19   Matchweek 1  Sat  Away      L  0  ...  11.0
# 2      2017-08-26   Matchweek 2  Sat  Home      D  2  ...  24.0
# 3      2017-08-26   Matchweek 2  Sat  Home      D  2  ...  16.0
# 4      2017-09-09   Matchweek 3  Sat  Home      W  3  ...   9.0
# ...           ...           ...  ...   ...    ... ..  ...   ...
# 49604  2024-03-10  Matchweek 28  Sun  Away      W  3  ...   6.0
# 49605  2024-03-17  Matchweek 29  Sun  Home      W  1  ...  14.0
# 49606  2024-03-17  Matchweek 29  Sun  Home      W  1  ...  12.0
# 49607  2024-04-01  Matchweek 30  Mon  Home      L  1  ...  14.0
# 49608  2024-04-01  Matchweek 30  Mon  Home      L  1  ...  11.0
#
#       Expected Goals Minus Goals  Home_Touches_Att 3rd  Home_Touches_Att Pen  \
# 0                           -0.8                  86.0                  12.0
# 1                            0.5                  86.0                  12.0
# 2                           -0.7                 172.0                  33.0
# 3                            0.7                 172.0                  33.0
# 4                            0.7                 118.0                  16.0
# ...                          ...                   ...                   ...
# 49604                        0.6                 158.0                  21.0
# 49605                       -1.1                 132.0                  29.0
# 49606                       -1.0                 132.0                  29.0
# 49607                        0.7                 173.0                  28.0
# 49608                        0.2                 173.0                  28.0
#
#        Away_Touches_Att 3rd  Away_Touches_Att Pen  Home_Shots  Away_Shots  \
# 0                     177.0                  34.0        11.0        11.0
# 1                     177.0                  34.0        11.0        11.0
# 2                      88.0                  20.0        16.0        16.0
# 3                      88.0                  20.0        16.0        16.0
# 4                     166.0                  20.0        13.0        13.0
# ...                     ...                   ...         ...         ...
# 49604                 119.0                  14.0         6.0         6.0
# 49605                 138.0                  21.0        12.0        12.0
# 49606                 138.0                  21.0        12.0        12.0
# 49607                 149.0                  21.0        11.0        11.0
# 49608                 149.0                  21.0        11.0        11.0
#
#        Home_Expected Goals Minus Goals  Away_Expected Goals Minus Goals
# 0                                  0.5                              0.5
# 1                                  0.5                              0.5
# 2                                  0.7                              0.7
# 3                                  0.7                              0.7
# 4                                 -0.7                             -0.7
# ...                                ...                              ...
# 49604                              0.6                              0.6
# 49605                             -1.0                             -1.0
# 49606                             -1.0                             -1.0
# 49607                              0.2                              0.2
# 49608                              0.2                              0.2
#
# [49609 rows x 49 columns]

# %%
combined_df.columns
# Out:
# Index(['league', 'season', 'team', 'game', 'date', 'round', 'day', 'venue',
#        'result', 'GF', 'GA', 'opponent', 'Poss', 'Touches_Touches',
#        'Touches_Def Pen', 'Touches_Def 3rd', 'Touches_Mid 3rd',
#        'Touches_Att 3rd', 'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att',
#        'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%',
#        'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC',
#        'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis',
#        'Receiving_Rec', 'Receiving_PrgR', 'time', 'match_report', 'home_team',
#        'away_team', 'Shots', 'Expected Goals Minus Goals',
#        'Home_Touches_Att 3rd', 'Home_Touches_Att Pen', 'Away_Touches_Att 3rd',
#        'Away_Touches_Att Pen', 'Home_Shots', 'Away_Shots',
#        'Home_Expected Goals Minus Goals', 'Away_Expected Goals Minus Goals'],
#       dtype='object')

# %%
# Columns to keep: first 9 and last 4
columns_to_keep = combined_df.columns.tolist()[:7] + combined_df.columns.tolist()[-12:]

# Selecting the specified columns
final_combined_df = combined_df[columns_to_keep]

# Display or use final_combined_df as needed
print(final_combined_df)
# Out:
#             league  season        team                                   game  \
# 0              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 1              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 2              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 3              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 4              NaN    1718    Augsburg               2017-09-09 Augsburg-Köln
# ...            ...     ...         ...                                    ...
# 49604  ESP-La Liga    2324  Villarreal            2024-03-10 Betis-Villarreal
# 49605  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49606  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49607  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
# 49608  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
#
#              date         round  day     home_team        away_team  Shots  \
# 0      2017-08-19   Matchweek 1  Sat  Hamburger SV         Augsburg   14.0
# 1      2017-08-19   Matchweek 1  Sat  Hamburger SV         Augsburg   11.0
# 2      2017-08-26   Matchweek 2  Sat      Augsburg       M'Gladbach   24.0
# 3      2017-08-26   Matchweek 2  Sat      Augsburg       M'Gladbach   16.0
# 4      2017-09-09   Matchweek 3  Sat      Augsburg             Köln    9.0
# ...           ...           ...  ...           ...              ...    ...
# 49604  2024-03-10  Matchweek 28  Sun         Betis       Villarreal    6.0
# 49605  2024-03-17  Matchweek 29  Sun    Villarreal         Valencia   14.0
# 49606  2024-03-17  Matchweek 29  Sun    Villarreal         Valencia   12.0
# 49607  2024-04-01  Matchweek 30  Mon    Villarreal  Atlético Madrid   14.0
# 49608  2024-04-01  Matchweek 30  Mon    Villarreal  Atlético Madrid   11.0
#
#        Expected Goals Minus Goals Home_Touches_Att 3rd Home_Touches_Att Pen  \
# 0                            -0.8                 86.0                 12.0
# 1                             0.5                 86.0                 12.0
# 2                            -0.7                172.0                 33.0
# 3                             0.7                172.0                 33.0
# 4                             0.7                118.0                 16.0
# ...                           ...                  ...                  ...
# 49604                         0.6                158.0                 21.0
# 49605                        -1.1                132.0                 29.0
# 49606                        -1.0                132.0                 29.0
# 49607                         0.7                173.0                 28.0
# 49608                         0.2                173.0                 28.0
#
#       Away_Touches_Att 3rd Away_Touches_Att Pen Home_Shots Away_Shots  \
# 0                    177.0                 34.0       11.0       11.0
# 1                    177.0                 34.0       11.0       11.0
# 2                     88.0                 20.0       16.0       16.0
# 3                     88.0                 20.0       16.0       16.0
# 4                    166.0                 20.0       13.0       13.0
# ...                    ...                  ...        ...        ...
# 49604                119.0                 14.0        6.0        6.0
# 49605                138.0                 21.0       12.0       12.0
# 49606                138.0                 21.0       12.0       12.0
# 49607                149.0                 21.0       11.0       11.0
# 49608                149.0                 21.0       11.0       11.0
#
#       Home_Expected Goals Minus Goals Away_Expected Goals Minus Goals
# 0                                 0.5                             0.5
# 1                                 0.5                             0.5
# 2                                 0.7                             0.7
# 3                                 0.7                             0.7
# 4                                -0.7                            -0.7
# ...                               ...                             ...
# 49604                             0.6                             0.6
# 49605                            -1.0                            -1.0
# 49606                            -1.0                            -1.0
# 49607                             0.2                             0.2
# 49608                             0.2                             0.2
#
# [49609 rows x 19 columns]

# %%
final_combined_df.columns
# Out:
# Index(['league', 'season', 'team', 'game', 'date', 'round', 'day', 'home_team',
#        'away_team', 'Shots', 'Expected Goals Minus Goals',
#        'Home_Touches_Att 3rd', 'Home_Touches_Att Pen', 'Away_Touches_Att 3rd',
#        'Away_Touches_Att Pen', 'Home_Shots', 'Away_Shots',
#        'Home_Expected Goals Minus Goals', 'Away_Expected Goals Minus Goals'],
#       dtype='object')

# %%
# Drop the specified columns from final_combined_df
final_combined_df = final_combined_df.drop(columns=[
    'Shots','Expected Goals Minus Goals'
])

# Display the DataFrame to confirm the columns have been removed
print(final_combined_df.head())
# Out:
#   league  season      team                              game        date  \
# 0    NaN    1718  Augsburg  2017-08-19 Hamburger SV-Augsburg  2017-08-19
# 1    NaN    1718  Augsburg  2017-08-19 Hamburger SV-Augsburg  2017-08-19
# 2    NaN    1718  Augsburg    2017-08-26 Augsburg-M'Gladbach  2017-08-26
# 3    NaN    1718  Augsburg    2017-08-26 Augsburg-M'Gladbach  2017-08-26
# 4    NaN    1718  Augsburg          2017-09-09 Augsburg-Köln  2017-09-09
#
#          round  day     home_team   away_team Home_Touches_Att 3rd  \
# 0  Matchweek 1  Sat  Hamburger SV    Augsburg                 86.0
# 1  Matchweek 1  Sat  Hamburger SV    Augsburg                 86.0
# 2  Matchweek 2  Sat      Augsburg  M'Gladbach                172.0
# 3  Matchweek 2  Sat      Augsburg  M'Gladbach                172.0
# 4  Matchweek 3  Sat      Augsburg        Köln                118.0
#
#   Home_Touches_Att Pen Away_Touches_Att 3rd Away_Touches_Att Pen Home_Shots  \
# 0                 12.0                177.0                 34.0       11.0
# 1                 12.0                177.0                 34.0       11.0
# 2                 33.0                 88.0                 20.0       16.0
# 3                 33.0                 88.0                 20.0       16.0
# 4                 16.0                166.0                 20.0       13.0
#
#   Away_Shots Home_Expected Goals Minus Goals Away_Expected Goals Minus Goals
# 0       11.0                             0.5                             0.5
# 1       11.0                             0.5                             0.5
# 2       16.0                             0.7                             0.7
# 3       16.0                             0.7                             0.7
# 4       13.0                            -0.7                            -0.7

# %%
import soccerdata as sd

# Assuming the Understat class accepts a list of seasons
# Correctly specify the seasons as a list of individual season strings
understat = sd.Understat(leagues=["ENG-Premier League", "ESP-La Liga", "GER-Bundesliga", "ITA-Serie A", "FRA-Ligue 1"], seasons=["2023/2024", "2022/2023", "2021/2022", "2020/2021", "2019/2020", "2018/2019", "2017/2018"])
team_match_stats = understat.read_team_match_stats()
team_match_stats = team_match_stats.reset_index()
# Convert the 'date' column to datetime
team_match_stats['date'] = pd.to_datetime(team_match_stats['date'])

team_match_stats['date'] = team_match_stats['date'].dt.date
team_match_stats.head()
# Out:
# [05/06/24 17:07:09] INFO     No custom team name replacements found. You can configure these in       ]8;id=755096;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=408336;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\jbuck\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=641486;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=981413;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_config.py#221\221]8;;\
#                              C:\Users\jbuck\soccerdata\config\league_dict.json.
#                     INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\Understat           ]8;id=973329;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=985067;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#92\92]8;;\
#                league season                                    game  \
# 0  ENG-Premier League   1718            2017-08-11 Arsenal-Leicester
# 1  ENG-Premier League   1718     2017-08-12 Brighton-Manchester City
# 2  ENG-Premier League   1718              2017-08-12 Chelsea-Burnley
# 3  ENG-Premier League   1718  2017-08-12 Crystal Palace-Huddersfield
# 4  ENG-Premier League   1718                2017-08-12 Everton-Stoke
#
#   league_id  season_id  game_id        date  home_team_id  away_team_id  \
# 0         1       2017     7119  2017-08-11            83            75
# 1         1       2017     7126  2017-08-12           220            88
# 2         1       2017     7123  2017-08-12            80            92
# 3         1       2017     7124  2017-08-12            78           219
# 4         1       2017     7125  2017-08-12            72            85
#
#         home_team  ...  away_ppda away_deep_completions home_points  \
# 0         Arsenal  ...  13.545455                     2           3
# 1        Brighton  ...   5.444444                    18           0
# 2         Chelsea  ...      23.75                     3           0
# 3  Crystal Palace  ...    6.90625                     5           0
# 4         Everton  ...      14.45                     9           3
#
#    home_expected_points  home_goals   home_xg  home_np_xg  \
# 0                2.0994           4   2.54329     2.54329
# 1                 0.173           0  0.276343    0.276343
# 2                2.0537           2   1.35651     1.35651
# 3                0.7084           0  0.988934    0.988934
# 4                1.7647           1  0.720574    0.720574
#
#    home_np_xg_difference  home_ppda  home_deep_completions
# 0                1.07834   5.444444                     13
# 1              -1.591167  67.333333                      2
# 2               0.792273   9.944444                      4
# 3              -0.747636        6.5                      3
# 4               0.444134   6.190476                      3
#
# [5 rows x 29 columns]

# %%
# Assuming `team_match_stats` and `final_combined_df` are already defined

# Collect all unique team names from home_team and away_team columns of team_match_stats
team_match_stats_teams = set(team_match_stats['home_team']).union(set(team_match_stats['away_team']))

# Collect all unique team names from home_team, away_team, and team columns of final_combined_df
final_combined_df_teams = set(final_combined_df['home_team']).union(set(final_combined_df['away_team']))
final_combined_df_teams = final_combined_df_teams.union(set(final_combined_df['team']))

# Find teams in team_match_stats that are not in final_combined_df
teams_not_in_final = team_match_stats_teams - final_combined_df_teams

# Find teams in final_combined_df that are not in team_match_stats
teams_not_in_team_match_stats = final_combined_df_teams - team_match_stats_teams

# Print the results
print("Teams in team_match_stats not in final_combined_df:", teams_not_in_final)
print("Teams in final_combined_df not in team_match_stats:", teams_not_in_team_match_stats)
# Out:
# Teams in team_match_stats not in final_combined_df: {'Leicester', 'Real Betis', 'Greuther Fuerth', 'SPAL 2013', 'Nottingham Forest', 'Manchester United', 'Verona', 'AC Milan', 'Wolverhampton Wanderers', 'Hertha Berlin', 'Malaga', 'RasenBallsport Leipzig', 'Cadiz', 'West Bromwich Albion', 'Sheffield United', 'Arminia Bielefeld', 'Atletico Madrid', 'Real Valladolid', 'Alaves', 'Paderborn', 'SD Huesca', 'Deportivo La Coruna', 'Leganes', 'Norwich', 'Eintracht Frankfurt', 'Swansea', 'Saint-Etienne', 'Borussia M.Gladbach', 'Bayer Leverkusen', 'Leeds', 'FC Heidenheim', 'VfB Stuttgart', 'Newcastle United', 'Parma Calcio 1913', 'Cardiff', 'FC Cologne', 'Nuernberg', 'Nimes', 'Almeria', 'Darmstadt', 'Fortuna Duesseldorf', 'Paris Saint Germain', 'Luton', 'Borussia Dortmund', 'Stoke'}
# Teams in final_combined_df not in team_match_stats: {'Swansea City', 'Leicester City', 'Köln', 'Qarabağ Ağdam', 'Young Boys', 'Paris S-G', 'Zürich', 'Málaga', 'TSC Bačka Top', 'Greuther Fürth', 'Parma', 'Cádiz', 'Dynamo Kyiv', 'Hertha BSC', 'Alavés', "Be'er Sheva", "Nott'ham Forest", 'Betis', 'Wolfsberger AC', 'Rangers', 'Ludogorets', 'Viktoria Plzeň', 'Eint Frankfurt', 'Ferencváros', 'Porto', 'Atlético Madrid', 'Nürnberg', 'Beşiktaş', 'Qarabağ', "Jahn R'burg", 'AÉK Lárnaka', 'Stoke City', 'Düsseldorf', 'Stuttgart', 'Rosenborg', 'Başakşehir', 'Slavia Prague', 'Milan', 'Leeds United', 'Union SG', 'Saint-Étienne', 'Olympiacos', 'Huesca', 'Arminia', 'Paderborn 07', 'Maccabi Haifa', 'Red Star', 'Malmö', 'Heidenheim', 'Benfica', 'Sporting CP', "M'Gladbach", 'Almería', 'Club Brugge', 'APOEL FC', 'RB Salzburg', 'Sheffield Utd', 'Leganés', 'Loko Moscow', 'Zorya Luhansk', 'RB Leipzig', 'Partizan', 'BATE Borisov', 'West Brom', 'Feyenoord', 'Nîmes', 'Darmstadt 98', 'Standard Liège', 'Slovácko', 'AEK Athens', 'Vitória', 'Apollon', 'Newcastle Utd', 'Aberdeen', 'PAOK', 'Leverkusen', 'SPAL', 'Ajax', 'Molde', 'Holstein Kiel', 'Zenit', 'Luton Town', 'La Coruña', 'Braga', 'Manchester Utd', 'HJK', 'Antwerp', 'Anderlecht', 'Östersund', 'St. Pauli', 'FC Copenhagen', 'FC Oleksandriya', 'Saarbrücken', 'Celtic', 'Fenerbahçe', 'Galatasaray', 'Valladolid', 'Cardiff City', 'Norwich City', 'Dortmund', 'Wolves', 'Hellas Verona', 'Slovan Liberec', 'Gent', 'Häcken', 'Shakhtar'}

# %%
# Complete mapping dictionary
name_mapping = {
    "Arminia": "Arminia Bielefeld",
    "Swansea City": "Swansea",
    "Leeds United": "Leeds",
    "Paris S-G": "Paris Saint Germain",
    "Greuther Fürth": "Greuther Fuerth",
    "Milan": "AC Milan",
    "Hellas Verona": "Verona",
    "Nürnberg": "Nuernberg",
    "RB Leipzig": "RasenBallsport Leipzig",
    "West Brom": "West Bromwich Albion",
    "Eint Frankfurt": "Eintracht Frankfurt",
    "Köln": "FC Cologne",
    "Stuttgart": "VfB Stuttgart",
    "Leverkusen": "Bayer Leverkusen",
    "Dortmund": "Borussia Dortmund",
    "Hertha BSC": "Hertha Berlin",
    "Atlético Madrid": "Atletico Madrid",
    "M'Gladbach": "Borussia M.Gladbach",
    "Wolves": "Wolverhampton Wanderers",
    "Cádiz": "Cadiz",
    "La Coruña": "Deportivo La Coruna",
    "Valladolid": "Real Valladolid",
    "Manchester Utd": "Manchester United",
    "Newcastle Utd": "Newcastle United",
    "Betis": "Real Betis",
    "Paderborn 07": "Paderborn",
    "Almería": "Almeria",
    "Luton Town": "Luton",
    "Norwich City": "Norwich",
    "Leicester City": "Leicester",
    "Cardiff City": "Cardiff",
    "Düsseldorf": "Fortuna Duesseldorf",
    "Saint-Étienne": "Saint-Etienne",
    "Heidenheim": "FC Heidenheim",
    "Leganés": "Leganes",
    "Qarabağ Ağdam": "Qarabağ",
    "SPAL": "SPAL 2013",
    "Nott'ham Forest": "Nottingham Forest",
    "Fortuna Duesseldorf": "Düsseldorf",
    "Parma": "Parma Calcio 1913",
    "FC Heidenheim": "Heidenheim",
    "Newcastle United": "Newcastle Utd",
    "Stoke": "Stoke City",
    "Alaves": "Alavés",
    "Malaga": "Málaga",
    "Verona": "Hellas Verona",
    "Real Valladolid": "Valladolid",
    "Borussia Dortmund": "Dortmund",
    "Borussia M.Gladbach": "M'Gladbach",
    "Wolverhampton Wanderers": "Wolves",
    "Real Betis": "Betis",
    "Paderborn": "Paderborn 07",
    "SD Huesca": "Huesca",
    "RasenBallsport Leipzig": "RB Leipzig",
    "Málaga": "Malaga",
    "Nîmes": "Nimes",
    "Stoke City": "Stoke",
    "Alavés": "Alaves",
    "Sheffield Utd": "Sheffield United",
    "Huesca": "SD Huesca",
    "Darmstadt 98": "Darmstadt",
    "Qarabağ": "Qarabağ Ağdam",
}


# Apply the mapping to the 'team', 'home_team', and 'away_team' columns in final_combined_df
final_combined_df['team'] = final_combined_df['team'].replace(name_mapping)
final_combined_df['home_team'] = final_combined_df['home_team'].replace(name_mapping)
final_combined_df['away_team'] = final_combined_df['away_team'].replace(name_mapping)

# %%
# Define the set of teams to be removed
teams_to_remove = {'FC Copenhagen', 'Aberdeen', "Be'er Sheva", 'Ferencváros', 'Partizan', 'Häcken', 'TSC Bačka Top', 
                   'Dynamo Kyiv', 'Porto', 'Slovan Liberec', 'Saarbrücken', 'Slavia Prague', 'Wolfsberger AC', 'Shakhtar',
                   'Rangers', 'AÉK Lárnaka', 'Holstein Kiel', 'PAOK', 'Union SG', 'Zenit', 'Vitória', 'Maccabi Haifa',
                   'Feyenoord', 'Ajax', 'Braga', 'St. Pauli', 'Red Star', 'Malmö', 'Beşiktaş', 'Club Brugge', 'Loko Moscow',
                   'FC Oleksandriya', 'Olympiacos', 'Molde', 'Apollon', 'Antwerp', 'Slovácko', 'Celtic', 'Galatasaray',
                   'Zorya Luhansk', 'HJK', 'Gent', 'Fenerbahçe', 'Benfica', 'Young Boys', 'BATE Borisov', 'Viktoria Plzeň',
                   "Jahn R'burg", 'Qarabağ Ağdam', 'Zürich', 'Sporting CP', 'RB Salzburg', 'AEK Athens', 'Başakşehir',
                   'Ludogorets', 'Qarabağ', 'Anderlecht', 'Östersund', 'Standard Liège', 'APOEL FC', 'Rosenborg'}

# Filtering out rows that contain any of the teams to be removed in either team, home_team, or away_team columns
final_combined_df = final_combined_df[
    ~final_combined_df['team'].isin(teams_to_remove) &
    ~final_combined_df['home_team'].isin(teams_to_remove) &
    ~final_combined_df['away_team'].isin(teams_to_remove)
]
# Remove duplicate rows based on all columns
final_combined_df = final_combined_df.drop_duplicates()

print("DataFrame after removing duplicates:")
print(final_combined_df)
# Out:
# DataFrame after removing duplicates:
#             league  season        team                                   game  \
# 0              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 2              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 4              NaN    1718    Augsburg               2017-09-09 Augsburg-Köln
# 6              NaN    1718    Augsburg     2017-09-16 Eint Frankfurt-Augsburg
# 8              NaN    1718    Augsburg         2017-09-19 Augsburg-RB Leipzig
# ...            ...     ...         ...                                    ...
# 49599  ESP-La Liga    2324  Villarreal    2024-02-23 Real Sociedad-Villarreal
# 49601  ESP-La Liga    2324  Villarreal          2024-03-03 Villarreal-Granada
# 49603  ESP-La Liga    2324  Villarreal            2024-03-10 Betis-Villarreal
# 49605  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49607  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
#
#              date         round  day            home_team  \
# 0      2017-08-19   Matchweek 1  Sat         Hamburger SV
# 2      2017-08-26   Matchweek 2  Sat             Augsburg
# 4      2017-09-09   Matchweek 3  Sat             Augsburg
# 6      2017-09-16   Matchweek 4  Sat  Eintracht Frankfurt
# 8      2017-09-19   Matchweek 5  Tue             Augsburg
# ...           ...           ...  ...                  ...
# 49599  2024-02-23  Matchweek 26  Fri        Real Sociedad
# 49601  2024-03-03  Matchweek 27  Sun           Villarreal
# 49603  2024-03-10  Matchweek 28  Sun           Real Betis
# 49605  2024-03-17  Matchweek 29  Sun           Villarreal
# 49607  2024-04-01  Matchweek 30  Mon           Villarreal
#
#                     away_team Home_Touches_Att 3rd Home_Touches_Att Pen  \
# 0                    Augsburg                 86.0                 12.0
# 2         Borussia M.Gladbach                172.0                 33.0
# 4                  FC Cologne                118.0                 16.0
# 6                    Augsburg                190.0                 35.0
# 8      RasenBallsport Leipzig                 92.0                 11.0
# ...                       ...                  ...                  ...
# 49599              Villarreal                246.0                 33.0
# 49601                 Granada                129.0                 15.0
# 49603              Villarreal                158.0                 21.0
# 49605                Valencia                132.0                 29.0
# 49607         Atletico Madrid                173.0                 28.0
#
#       Away_Touches_Att 3rd Away_Touches_Att Pen Home_Shots Away_Shots  \
# 0                    177.0                 34.0       11.0       11.0
# 2                     88.0                 20.0       16.0       16.0
# 4                    166.0                 20.0       13.0       13.0
# 6                     92.0                 18.0       23.0       23.0
# 8                    185.0                 26.0       14.0       14.0
# ...                    ...                  ...        ...        ...
# 49599                 53.0                 15.0        6.0        6.0
# 49601                163.0                 19.0       16.0       16.0
# 49603                119.0                 14.0        6.0        6.0
# 49605                138.0                 21.0       12.0       12.0
# 49607                149.0                 21.0       11.0       11.0
#
#       Home_Expected Goals Minus Goals Away_Expected Goals Minus Goals
# 0                                 0.5                             0.5
# 2                                 0.7                             0.7
# 4                                -0.7                            -0.7
# 6                                -0.5                            -0.5
# 8                                -1.1                            -1.1
# ...                               ...                             ...
# 49599                             2.0                             2.0
# 49601                             3.0                             3.0
# 49603                             0.6                             0.6
# 49605                            -1.0                            -1.0
# 49607                             0.2                             0.2
#
# [24741 rows x 17 columns]

# %%
import pandas as pd

# Assuming final_combined_df and team_match_stats are already loaded into pandas DataFrames

# Convert 'date' column to datetime if it's not already (uncomment if necessary)
final_combined_df['date'] = pd.to_datetime(final_combined_df['date'])
team_match_stats['date'] = pd.to_datetime(team_match_stats['date'])

# Correcting the team name to match exactly how it's stored in team_match_stats
filtered_team_match_stats = team_match_stats.query(
    "home_team == 'Arsenal' and away_team == 'Leicester' and date == '2017-08-11'"
)

# Filtering for final_combined_df, where it seems the team names are correct as shown in your output
filtered_final_combined_df = final_combined_df.query(
    "home_team == 'Arsenal' and away_team == 'Leicester' and date == '2017-08-11'"
)

# Printing the filtered rows from both dataframes
print("Filtered rows from final_combined_df:")
print(filtered_final_combined_df)

print("Filtered rows from team_match_stats:")
print(filtered_team_match_stats)
# Out:
# Filtered rows from final_combined_df:
#                   league  season       team  \
# 8947  ENG-Premier League    1718    Arsenal
# 9555  ENG-Premier League    1718  Leicester
#
#                                    game       date        round  day  \
# 8947  2017-08-11 Arsenal-Leicester City 2017-08-11  Matchweek 1  Fri
# 9555  2017-08-11 Arsenal-Leicester City 2017-08-11  Matchweek 1  Fri
#
#      home_team  away_team Home_Touches_Att 3rd Home_Touches_Att Pen  \
# 8947   Arsenal  Leicester                252.0                 30.0
# 9555   Arsenal  Leicester                252.0                 30.0
#
#      Away_Touches_Att 3rd Away_Touches_Att Pen Home_Shots Away_Shots  \
# 8947                120.0                 11.0        6.0        6.0
# 9555                120.0                 11.0        6.0        6.0
#
#      Home_Expected Goals Minus Goals Away_Expected Goals Minus Goals
# 8947                             1.5                             1.5
# 9555                             1.5                             1.5
# Filtered rows from team_match_stats:
#                league season                          game league_id  \
# 0  ENG-Premier League   1718  2017-08-11 Arsenal-Leicester         1
#
#    season_id  game_id       date  home_team_id  away_team_id home_team  ...  \
# 0       2017     7119 2017-08-11            83            75   Arsenal  ...
#
#    away_ppda away_deep_completions home_points  home_expected_points  \
# 0  13.545455                     2           3                2.0994
#
#    home_goals  home_xg  home_np_xg  home_np_xg_difference  home_ppda  \
# 0           4  2.54329     2.54329                1.07834   5.444444
#
#    home_deep_completions
# 0                     13
#
# [1 rows x 29 columns]

# %%
team_match_stats.iloc[0]
# Out:
# league                             ENG-Premier League
# season                                           1718
# game                     2017-08-11 Arsenal-Leicester
# league_id                                           1
# season_id                                        2017
# game_id                                          7119
# date                              2017-08-11 00:00:00
# home_team_id                                       83
# away_team_id                                       75
# home_team                                     Arsenal
# away_team                                   Leicester
# away_team_code                                    LEI
# home_team_code                                    ARS
# away_points                                         0
# away_expected_points                           0.6852
# away_goals                                          3
# away_xg                                       1.46495
# away_np_xg                                    1.46495
# away_np_xg_difference                        -1.07834
# away_ppda                                   13.545455
# away_deep_completions                               2
# home_points                                         3
# home_expected_points                           2.0994
# home_goals                                          4
# home_xg                                       2.54329
# home_np_xg                                    2.54329
# home_np_xg_difference                         1.07834
# home_ppda                                    5.444444
# home_deep_completions                              13
# Name: 0, dtype: object

# %%
stat_columns = [
    'Home_Touches_Att 3rd', 'Home_Touches_Att Pen',
    'Away_Touches_Att 3rd', 'Away_Touches_Att Pen', 
    'Home_Shots', 'Away_Shots',
    'Home_Expected Goals Minus Goals', 'Away_Expected Goals Minus Goals'
]
print(final_combined_df[stat_columns].isnull().sum())
# Out:
# Home_Touches_Att 3rd               0
# Home_Touches_Att Pen               0
# Away_Touches_Att 3rd               0
# Away_Touches_Att Pen               0
# Home_Shots                         0
# Away_Shots                         0
# Home_Expected Goals Minus Goals    0
# Away_Expected Goals Minus Goals    0
# dtype: int64

# %%
import pandas as pd

# Assuming final_combined_df is already loaded as a DataFrame

# List of specific statistics columns where NaN values should lead to row removal
stat_columns = [
    'Home_Touches_Att 3rd', 'Home_Touches_Att Pen',
    'Away_Touches_Att 3rd', 'Away_Touches_Att Pen', 
    'Home_Shots', 'Away_Shots',
    'Home_Expected Goals Minus Goals', 'Away_Expected Goals Minus Goals'
]

# Drop rows that have NaN values in any of the specified stat columns
final_combined_df = final_combined_df.dropna(subset=stat_columns)

# Optionally, print the DataFrame to confirm rows have been dropped
print(final_combined_df)
# Out:
#             league  season        team                                   game  \
# 0              NaN    1718    Augsburg       2017-08-19 Hamburger SV-Augsburg
# 2              NaN    1718    Augsburg         2017-08-26 Augsburg-M'Gladbach
# 4              NaN    1718    Augsburg               2017-09-09 Augsburg-Köln
# 6              NaN    1718    Augsburg     2017-09-16 Eint Frankfurt-Augsburg
# 8              NaN    1718    Augsburg         2017-09-19 Augsburg-RB Leipzig
# ...            ...     ...         ...                                    ...
# 49599  ESP-La Liga    2324  Villarreal    2024-02-23 Real Sociedad-Villarreal
# 49601  ESP-La Liga    2324  Villarreal          2024-03-03 Villarreal-Granada
# 49603  ESP-La Liga    2324  Villarreal            2024-03-10 Betis-Villarreal
# 49605  ESP-La Liga    2324  Villarreal         2024-03-17 Villarreal-Valencia
# 49607  ESP-La Liga    2324  Villarreal  2024-04-01 Villarreal-Atlético Madrid
#
#             date         round  day            home_team  \
# 0     2017-08-19   Matchweek 1  Sat         Hamburger SV
# 2     2017-08-26   Matchweek 2  Sat             Augsburg
# 4     2017-09-09   Matchweek 3  Sat             Augsburg
# 6     2017-09-16   Matchweek 4  Sat  Eintracht Frankfurt
# 8     2017-09-19   Matchweek 5  Tue             Augsburg
# ...          ...           ...  ...                  ...
# 49599 2024-02-23  Matchweek 26  Fri        Real Sociedad
# 49601 2024-03-03  Matchweek 27  Sun           Villarreal
# 49603 2024-03-10  Matchweek 28  Sun           Real Betis
# 49605 2024-03-17  Matchweek 29  Sun           Villarreal
# 49607 2024-04-01  Matchweek 30  Mon           Villarreal
#
#                     away_team Home_Touches_Att 3rd Home_Touches_Att Pen  \
# 0                    Augsburg                 86.0                 12.0
# 2         Borussia M.Gladbach                172.0                 33.0
# 4                  FC Cologne                118.0                 16.0
# 6                    Augsburg                190.0                 35.0
# 8      RasenBallsport Leipzig                 92.0                 11.0
# ...                       ...                  ...                  ...
# 49599              Villarreal                246.0                 33.0
# 49601                 Granada                129.0                 15.0
# 49603              Villarreal                158.0                 21.0
# 49605                Valencia                132.0                 29.0
# 49607         Atletico Madrid                173.0                 28.0
#
#       Away_Touches_Att 3rd Away_Touches_Att Pen Home_Shots Away_Shots  \
# 0                    177.0                 34.0       11.0       11.0
# 2                     88.0                 20.0       16.0       16.0
# 4                    166.0                 20.0       13.0       13.0
# 6                     92.0                 18.0       23.0       23.0
# 8                    185.0                 26.0       14.0       14.0
# ...                    ...                  ...        ...        ...
# 49599                 53.0                 15.0        6.0        6.0
# 49601                163.0                 19.0       16.0       16.0
# 49603                119.0                 14.0        6.0        6.0
# 49605                138.0                 21.0       12.0       12.0
# 49607                149.0                 21.0       11.0       11.0
#
#       Home_Expected Goals Minus Goals Away_Expected Goals Minus Goals
# 0                                 0.5                             0.5
# 2                                 0.7                             0.7
# 4                                -0.7                            -0.7
# 6                                -0.5                            -0.5
# 8                                -1.1                            -1.1
# ...                               ...                             ...
# 49599                             2.0                             2.0
# 49601                             3.0                             3.0
# 49603                             0.6                             0.6
# 49605                            -1.0                            -1.0
# 49607                             0.2                             0.2
#
# [24600 rows x 17 columns]

# %%
import pandas as pd

# Assuming you have already loaded your DataFrames `final_combined_df` and `team_match_stats`
# and defined them as per the columns listed.

# Filter the necessary columns from final_combined_df
columns_to_merge = [
    'date', 'home_team', 'away_team', 'Home_Touches_Att 3rd', 'Home_Touches_Att Pen',
    'Away_Touches_Att 3rd', 'Away_Touches_Att Pen', 'Home_Shots', 'Away_Shots',
    'Home_Expected Goals Minus Goals', 'Away_Expected Goals Minus Goals'
]
final_combined_filtered = final_combined_df[columns_to_merge]

# Drop duplicates to keep only the first match instance per unique date, home_team, and away_team
final_combined_unique = final_combined_filtered.drop_duplicates(subset=['date', 'home_team', 'away_team'])

# Merging the unique data with team_match_stats on 'date', 'home_team', 'away_team'
team_match_stats = team_match_stats.merge(final_combined_unique, how='left', 
                                          left_on=['date', 'home_team', 'away_team'], 
                                          right_on=['date', 'home_team', 'away_team'])

# Now team_match_stats should have the additional columns merged in from final_combined_df
team_match_stats
# Out:
#                    league season                                    game  \
# 0      ENG-Premier League   1718            2017-08-11 Arsenal-Leicester
# 1      ENG-Premier League   1718     2017-08-12 Brighton-Manchester City
# 2      ENG-Premier League   1718              2017-08-12 Chelsea-Burnley
# 3      ENG-Premier League   1718  2017-08-12 Crystal Palace-Huddersfield
# 4      ENG-Premier League   1718                2017-08-12 Everton-Stoke
# ...                   ...    ...                                     ...
# 12470         ITA-Serie A   2324             2024-05-05 Empoli-Frosinone
# 12471         ITA-Serie A   2324                2024-05-05 Roma-Juventus
# 12472         ITA-Serie A   2324            2024-05-05 Verona-Fiorentina
# 12473         ITA-Serie A   2324         2024-05-06 Salernitana-Atalanta
# 12474         ITA-Serie A   2324               2024-05-06 Udinese-Napoli
#
#       league_id  season_id  game_id       date  home_team_id  away_team_id  \
# 0             1       2017     7119 2017-08-11            83            75
# 1             1       2017     7126 2017-08-12           220            88
# 2             1       2017     7123 2017-08-12            80            92
# 3             1       2017     7124 2017-08-12            78           219
# 4             1       2017     7125 2017-08-12            72            85
# ...         ...        ...      ...        ...           ...           ...
# 12470         2       2023    22646 2024-05-05           108           112
# 12471         2       2023    22652 2024-05-05            95            98
# 12472         2       2023    22649 2024-05-05            94           110
# 12473         2       2023    22647 2024-05-06           264           107
# 12474         2       2023    22654 2024-05-06            99           105
#
#             home_team  ...  home_ppda home_deep_completions  \
# 0             Arsenal  ...   5.444444                    13
# 1            Brighton  ...  67.333333                     2
# 2             Chelsea  ...   9.944444                     4
# 3      Crystal Palace  ...        6.5                     3
# 4             Everton  ...   6.190476                     3
# ...               ...  ...        ...                   ...
# 12470          Empoli  ...   7.227273                     3
# 12471            Roma  ...  11.733333                     7
# 12472          Verona  ...  11.545455                     4
# 12473     Salernitana  ...  15.954545                     4
# 12474         Udinese  ...     21.875                     4
#
#       Home_Touches_Att 3rd  Home_Touches_Att Pen  Away_Touches_Att 3rd  \
# 0                    252.0                  30.0                 120.0
# 1                     51.0                   9.0                 298.0
# 2                    203.0                  23.0                  74.0
# 3                    113.0                  19.0                 127.0
# 4                    142.0                  22.0                 135.0
# ...                    ...                   ...                   ...
# 12470                  NaN                   NaN                   NaN
# 12471                  NaN                   NaN                   NaN
# 12472                  NaN                   NaN                   NaN
# 12473                  NaN                   NaN                   NaN
# 12474                  NaN                   NaN                   NaN
#
#        Away_Touches_Att Pen  Home_Shots  Away_Shots  \
# 0                      11.0         6.0         6.0
# 1                      27.0        14.0        14.0
# 2                      11.0        19.0        19.0
# 3                      13.0         9.0         9.0
# 4                      16.0         9.0         9.0
# ...                     ...         ...         ...
# 12470                   NaN         NaN         NaN
# 12471                   NaN         NaN         NaN
# 12472                   NaN         NaN         NaN
# 12473                   NaN         NaN         NaN
# 12474                   NaN         NaN         NaN
#
#        Home_Expected Goals Minus Goals  Away_Expected Goals Minus Goals
# 0                                  1.5                              1.5
# 1                                 -0.9                             -0.9
# 2                                  0.5                              0.5
# 3                                  0.5                              0.5
# 4                                 -0.4                             -0.4
# ...                                ...                              ...
# 12470                              NaN                              NaN
# 12471                              NaN                              NaN
# 12472                              NaN                              NaN
# 12473                              NaN                              NaN
# 12474                              NaN                              NaN
#
# [12475 rows x 37 columns]

# %%
# Drop rows that have NaN values in any of the specified stat columns
team_match_stats = team_match_stats.dropna(subset=stat_columns)

# Optionally, print the DataFrame to confirm rows have been dropped
print(team_match_stats)
# Out:
#                    league season                                    game  \
# 0      ENG-Premier League   1718            2017-08-11 Arsenal-Leicester
# 1      ENG-Premier League   1718     2017-08-12 Brighton-Manchester City
# 2      ENG-Premier League   1718              2017-08-12 Chelsea-Burnley
# 3      ENG-Premier League   1718  2017-08-12 Crystal Palace-Huddersfield
# 4      ENG-Premier League   1718                2017-08-12 Everton-Stoke
# ...                   ...    ...                                     ...
# 12421         ITA-Serie A   2324              2024-04-01 Cagliari-Verona
# 12422         ITA-Serie A   2324                 2024-04-01 Inter-Empoli
# 12423         ITA-Serie A   2324                   2024-04-01 Lecce-Roma
# 12424         ITA-Serie A   2324             2024-04-01 Sassuolo-Udinese
# 12425         ITA-Serie A   2324         2024-04-05 Salernitana-Sassuolo
#
#       league_id  season_id  game_id       date  home_team_id  away_team_id  \
# 0             1       2017     7119 2017-08-11            83            75
# 1             1       2017     7126 2017-08-12           220            88
# 2             1       2017     7123 2017-08-12            80            92
# 3             1       2017     7124 2017-08-12            78           219
# 4             1       2017     7125 2017-08-12            72            85
# ...         ...        ...      ...        ...           ...           ...
# 12421         2       2023    22595 2024-04-01           116            94
# 12422         2       2023    22599 2024-04-01           106           108
# 12423         2       2023    22600 2024-04-01           243            95
# 12424         2       2023    22597 2024-04-01           104            99
# 12425         2       2023    22611 2024-04-05           264           104
#
#             home_team  ...  home_ppda home_deep_completions  \
# 0             Arsenal  ...   5.444444                    13
# 1            Brighton  ...  67.333333                     2
# 2             Chelsea  ...   9.944444                     4
# 3      Crystal Palace  ...        6.5                     3
# 4             Everton  ...   6.190476                     3
# ...               ...  ...        ...                   ...
# 12421        Cagliari  ...   7.478261                     1
# 12422           Inter  ...    9.73913                    12
# 12423           Lecce  ...  15.947368                     4
# 12424        Sassuolo  ...  10.052632                     8
# 12425     Salernitana  ...  14.642857                     2
#
#       Home_Touches_Att 3rd  Home_Touches_Att Pen  Away_Touches_Att 3rd  \
# 0                    252.0                  30.0                 120.0
# 1                     51.0                   9.0                 298.0
# 2                    203.0                  23.0                  74.0
# 3                    113.0                  19.0                 127.0
# 4                    142.0                  22.0                 135.0
# ...                    ...                   ...                   ...
# 12421                136.0                  20.0                  92.0
# 12422                186.0                  35.0                 121.0
# 12423                107.0                  22.0                 134.0
# 12424                165.0                  26.0                  91.0
# 12425                114.0                  11.0                 146.0
#
#        Away_Touches_Att Pen  Home_Shots  Away_Shots  \
# 0                      11.0         6.0         6.0
# 1                      27.0        14.0        14.0
# 2                      11.0        19.0        19.0
# 3                      13.0         9.0         9.0
# 4                      16.0         9.0         9.0
# ...                     ...         ...         ...
# 12421                  11.0         8.0         8.0
# 12422                  19.0        19.0        19.0
# 12423                  15.0        10.0        10.0
# 12424                  16.0        12.0        12.0
# 12425                  31.0        16.0        16.0
#
#        Home_Expected Goals Minus Goals  Away_Expected Goals Minus Goals
# 0                                  1.5                              1.5
# 1                                 -0.9                             -0.9
# 2                                  0.5                              0.5
# 3                                  0.5                              0.5
# 4                                 -0.4                             -0.4
# ...                                ...                              ...
# 12421                             -0.4                             -0.4
# 12422                             -0.1                             -0.1
# 12423                             -1.3                             -1.3
# 12424                             -0.5                             -0.5
# 12425                             -0.3                             -0.3
#
# [12221 rows x 37 columns]

# %%
import pandas as pd

# Assuming the DataFrame is already loaded as team_match_stats

# Filter rows where any column has null values
rows_with_nulls = team_match_stats[team_match_stats.isnull().any(axis=1)]

# Get unique names from 'home_team' and 'away_team' where there are nulls in other columns
unique_home_teams_with_nulls = rows_with_nulls['home_team'].unique()
unique_away_teams_with_nulls = rows_with_nulls['away_team'].unique()

# Print the results
print("Unique home teams with null values in other columns:")
print(unique_home_teams_with_nulls)

print("Unique away teams with null values in other columns:")
print(unique_away_teams_with_nulls)
# Out:
# Unique home teams with null values in other columns:
# []
# Unique away teams with null values in other columns:
# []

# %%
team_match_stats = team_match_stats.drop_duplicates(subset=['date', 'home_team', 'away_team'])

# %%
team_match_stats.columns
# Out:
# Index(['league', 'season', 'game', 'league_id', 'season_id', 'game_id', 'date',
#        'home_team_id', 'away_team_id', 'home_team', 'away_team',
#        'away_team_code', 'home_team_code', 'away_points',
#        'away_expected_points', 'away_goals', 'away_xg', 'away_np_xg',
#        'away_np_xg_difference', 'away_ppda', 'away_deep_completions',
#        'home_points', 'home_expected_points', 'home_goals', 'home_xg',
#        'home_np_xg', 'home_np_xg_difference', 'home_ppda',
#        'home_deep_completions', 'Home_Touches_Att 3rd', 'Home_Touches_Att Pen',
#        'Away_Touches_Att 3rd', 'Away_Touches_Att Pen', 'Home_Shots',
#        'Away_Shots', 'Home_Expected Goals Minus Goals',
#        'Away_Expected Goals Minus Goals'],
#       dtype='object')

# %%
team_match_stats.to_csv('all_stats_engineered_for_model.csv', index=False)
# Cell 1: Check current branch
# !git branch

# Cell 2: Add CSV file to Git
# !git add all_stats_engineered_for_model.csv

# Cell 3: Commit changes
# !git commit -m "Added corresponding CSV data"

# Cell 4: Push to GitHub (assuming the current branch is 'main')
# !git push origin main
# Out:
# * main
# [main 935f8e7] Added corresponding CSV data
#  1 file changed, 12222 insertions(+)
#  create mode 100644 all_stats_engineered_for_model.csv
# To https://github.com/Jbuck1016/Predicting-Matches
#    0ddea00..935f8e7  main -> main

# %%
# !git add expanding_out_dataframes.ipynb

# Cell 3: Commit changes
# !git commit -m "Added Jupyter notebook"

# Cell 4: Push to GitHub
# !git push origin main
# Out:
# warning: in the working copy of 'expanding_out_dataframes.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main f82b75a] Added Jupyter notebook
#  1 file changed, 52 insertions(+), 8 deletions(-)
# To https://github.com/Jbuck1016/Predicting-Matches
#    935f8e7..f82b75a  main -> main

# %%
team_match_stats
# Out:
#                    league season                                    game  \
# 0      ENG-Premier League   1718            2017-08-11 Arsenal-Leicester
# 1      ENG-Premier League   1718     2017-08-12 Brighton-Manchester City
# 2      ENG-Premier League   1718              2017-08-12 Chelsea-Burnley
# 3      ENG-Premier League   1718  2017-08-12 Crystal Palace-Huddersfield
# 4      ENG-Premier League   1718                2017-08-12 Everton-Stoke
# ...                   ...    ...                                     ...
# 12421         ITA-Serie A   2324              2024-04-01 Cagliari-Verona
# 12422         ITA-Serie A   2324                 2024-04-01 Inter-Empoli
# 12423         ITA-Serie A   2324                   2024-04-01 Lecce-Roma
# 12424         ITA-Serie A   2324             2024-04-01 Sassuolo-Udinese
# 12425         ITA-Serie A   2324         2024-04-05 Salernitana-Sassuolo
#
#       league_id  season_id  game_id       date  home_team_id  away_team_id  \
# 0             1       2017     7119 2017-08-11            83            75
# 1             1       2017     7126 2017-08-12           220            88
# 2             1       2017     7123 2017-08-12            80            92
# 3             1       2017     7124 2017-08-12            78           219
# 4             1       2017     7125 2017-08-12            72            85
# ...         ...        ...      ...        ...           ...           ...
# 12421         2       2023    22595 2024-04-01           116            94
# 12422         2       2023    22599 2024-04-01           106           108
# 12423         2       2023    22600 2024-04-01           243            95
# 12424         2       2023    22597 2024-04-01           104            99
# 12425         2       2023    22611 2024-04-05           264           104
#
#             home_team  ...  home_ppda home_deep_completions  \
# 0             Arsenal  ...   5.444444                    13
# 1            Brighton  ...  67.333333                     2
# 2             Chelsea  ...   9.944444                     4
# 3      Crystal Palace  ...        6.5                     3
# 4             Everton  ...   6.190476                     3
# ...               ...  ...        ...                   ...
# 12421        Cagliari  ...   7.478261                     1
# 12422           Inter  ...    9.73913                    12
# 12423           Lecce  ...  15.947368                     4
# 12424        Sassuolo  ...  10.052632                     8
# 12425     Salernitana  ...  14.642857                     2
#
#       Home_Touches_Att 3rd  Home_Touches_Att Pen  Away_Touches_Att 3rd  \
# 0                    252.0                  30.0                 120.0
# 1                     51.0                   9.0                 298.0
# 2                    203.0                  23.0                  74.0
# 3                    113.0                  19.0                 127.0
# 4                    142.0                  22.0                 135.0
# ...                    ...                   ...                   ...
# 12421                136.0                  20.0                  92.0
# 12422                186.0                  35.0                 121.0
# 12423                107.0                  22.0                 134.0
# 12424                165.0                  26.0                  91.0
# 12425                114.0                  11.0                 146.0
#
#        Away_Touches_Att Pen  Home_Shots  Away_Shots  \
# 0                      11.0         6.0         6.0
# 1                      27.0        14.0        14.0
# 2                      11.0        19.0        19.0
# 3                      13.0         9.0         9.0
# 4                      16.0         9.0         9.0
# ...                     ...         ...         ...
# 12421                  11.0         8.0         8.0
# 12422                  19.0        19.0        19.0
# 12423                  15.0        10.0        10.0
# 12424                  16.0        12.0        12.0
# 12425                  31.0        16.0        16.0
#
#        Home_Expected Goals Minus Goals  Away_Expected Goals Minus Goals
# 0                                  1.5                              1.5
# 1                                 -0.9                             -0.9
# 2                                  0.5                              0.5
# 3                                  0.5                              0.5
# 4                                 -0.4                             -0.4
# ...                                ...                              ...
# 12421                             -0.4                             -0.4
# 12422                             -0.1                             -0.1
# 12423                             -1.3                             -1.3
# 12424                             -0.5                             -0.5
# 12425                             -0.3                             -0.3
#
# [12221 rows x 37 columns]

# %%
import pandas as pd
import soccerdata as sd

# Initialize the MatchHistory object
mh = sd.MatchHistory(leagues=["ITA-Serie A", "ENG-Premier League", "ESP-La Liga", "FRA-Ligue 1", "GER-Bundesliga"],
                     seasons=["23", "22", "21", "20", "19", "18"])

hist = mh.read_games()
hist.reset_index(inplace=True)
hist.head()
# Out:
# [05/06/24 19:05:52] INFO     Saving cached data to C:\Users\jbuck\soccerdata\data\MatchHistory        ]8;id=514062;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=264896;file://C:\Users\jbuck\anaconda3\Lib\site-packages\soccerdata\_common.py#92\92]8;;\
#                league season                              game  \
# 0  ENG-Premier League   1819   2018-08-10 Man United-Leicester
# 1  ENG-Premier League   1819    2018-08-11 Bournemouth-Cardiff
# 2  ENG-Premier League   1819  2018-08-11 Fulham-Crystal Palace
# 3  ENG-Premier League   1819   2018-08-11 Huddersfield-Chelsea
# 4  ENG-Premier League   1819    2018-08-11 Newcastle-Tottenham
#
#                  date     home_team       away_team  FTHG  FTAG FTR  HTHG  \
# 0 2018-08-10 12:00:00    Man United       Leicester     2     1   H     1
# 1 2018-08-11 12:00:00   Bournemouth         Cardiff     2     0   H     1
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame loaded with the data

# List of columns you want to keep
columns_to_keep = ['league', 'season', 'game', 'date', 'home_team', 'away_team', 'B365H', 'B365D', 'B365A']

# Drop all other columns
hist = hist[columns_to_keep]
import pandas as pd

# Assuming 'df' is your DataFrame

# Convert 'date' to datetime if it's not already
hist['date'] = pd.to_datetime(hist['date'])

# Extract only the date part
hist['date'] = hist['date'].dt.date


# Now 'df' only contains the columns specified
hist
# Out:
#                    league season                              game  \
# 0      ENG-Premier League   1819   2018-08-10 Man United-Leicester
# 1      ENG-Premier League   1819    2018-08-11 Bournemouth-Cardiff
# 2      ENG-Premier League   1819  2018-08-11 Fulham-Crystal Palace
# 3      ENG-Premier League   1819   2018-08-11 Huddersfield-Chelsea
# 4      ENG-Premier League   1819    2018-08-11 Newcastle-Tottenham
# ...                   ...    ...                               ...
# 10644         ITA-Serie A   2324            2024-05-05 Milan-Genoa
# 10645         ITA-Serie A   2324          2024-05-05 Roma-Juventus
# 10646         ITA-Serie A   2324      2024-05-05 Verona-Fiorentina
# 10647         ITA-Serie A   2324   2024-05-06 Salernitana-Atalanta
# 10648         ITA-Serie A   2324         2024-05-06 Udinese-Napoli
#
#              date     home_team       away_team  B365H  B365D  B365A
# 0      2018-08-10    Man United       Leicester   1.57    3.9   7.50
# ...

# %%
hist.to_csv('odds_data_for_model.csv', index=False)
# Cell 1: Check current branch
# !git branch

# Cell 2: Add CSV file to Git
# !git add odds_data_for_model.csv

# Cell 3: Commit changes
# !git commit -m "Added corresponding CSV data"

# Cell 4: Push to GitHub (assuming the current branch is 'main')
# !git push origin main
# Out:
# * main
# [main 40c082a] Added corresponding CSV data
#  1 file changed, 10650 insertions(+)
#  create mode 100644 odds_data_for_model.csv
# To https://github.com/Jbuck1016/Predicting-Matches
#    7199fe6..40c082a  main -> main

# %%
# !git add Loading_In_Odds_Data.ipynb

# Cell 3: Commit changes
# !git commit -m "Added Jupyter notebook"

# Cell 4: Push to GitHub
# !git push origin main
# Out:
# ...
# [main f24b674] Added Jupyter notebook
#  1 file changed, 272 insertions(+)
#  create mode 100644 Loading_In_Odds_Data.ipynb
# To https://github.com/Jbuck1016/Predicting-Matches
#    40c082a..f24b674  main -> main
